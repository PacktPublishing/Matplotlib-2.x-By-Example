# %% [markdown]
# Figure aesthetics
# ==

# %% [markdown]
# ___
# # Setting colors in Matplotlib

# %% [markdown]
# ## Using specific colors in the color cycle

# %%
import matplotlib.pyplot as plt
# Global smartphone sales by operating system in 2009-2016 (in Millions)
# Data were collected from Statista
#
# https://www.statista.com/statistics/263445/global-smartphone-sales-by-operating-system-since-2009/
# Data were published by Gartner in Feb 2017
years = list(range(2009,2017))
android = [6.8,67.22,220.67,451.62,761.29,1004.68,1160.21,1271.02]
ios = [24.89,46.6,89.27,130.13,150.79,191.43,225.85,216.07]
microsoft = [15.03,12.38,8.76,16.94,30.71,35.13,26.74,6.94]

plt.plot(years,android,label='Android')
# color='C0' by default
plt.plot(years,ios,label='iOS')
# color='C1' by default
plt.plot(years,microsoft,label='Microsoft') # color='C2' by default
plt.legend()
plt.show()

# %% [markdown]
# ## Aesthetic and readability considerations

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# Prepare 4 lines with different slopes
x = np.linspace(0,200,100) # Prepare 100 evenly spaced numbers from 0 to
200
y1 = x*2
y2 = x*3
y3 = x*4
y4 = x*5
# Set line width to 2 for clarity
mpl.rcParams['lines.linewidth'] = 2
# Drawing the 4 lines
plt.plot(x,y1,label = '2x', c='0')                   # Black solid line
plt.plot(x,y2,label = '3x', c='0.2', ls='--')        # Dark grey dashed line
plt.plot(x,y3,label = '4x', c='0.4', ls='-.')        # Grey dash-dot line
plt.plot(x,y4,label = '5x', c='0.6', ls=':')         # Light grey dotted line
plt.legend()
plt.show()

# %%
# This is a negative example
# Draw the 4 lines
# this line is too faint
plt.plot(x,y1,label = '2x', c='0.9') # light grey
# this line is barely visible
plt.plot(x,y2,label = '3x', c='0.99') # very faint grey line
# these two lines have too little contrast and may be confusing
plt.plot(x,y3,label = '4x', c='0.4') # grey
plt.plot(x,y4,label = '5x', c='0.45') # slightly lighter grey
plt.legend()
plt.show()

# %% [markdown]
# ___
# # Adjusting text formats

# %% [markdown]
# ## Font

# %% [markdown]
# ### Font appearance

# %%
import matplotlib.pyplot as plt
fontparams = {'size':16,'fontweight':'light','family':'monospace','style':'normal'}
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)
plt.xlabel('xlabel',size=20,fontweight='semibold',family='serif',style='italic')
plt.ylabel('ylabel',fontparams)
plt.show()

# %% [markdown]
# ## Checking available fonts in system

# %%
# Run this cell to see the fonts installed in your system
from matplotlib.font_manager import findSystemFonts
findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# ['/usr/share/fonts/truetype/kacst/KacstTitleL.ttf',
#  '/home/claire/.fonts/fonts/Arimo/Arimo Italic for Powerline.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
#  '/home/claire/.fonts/fonts/Cousine/Cousine Bold for Powerline.ttf',
#  '/usr/share/fonts/truetype/lao/Phetsarath_OT.ttf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono for Powerline.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeSerifItalic.ttf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsUpSm-Bold.otf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-BI.ttf',
#  '/home/claire/.fonts/fonts/Hack/Hack-Bold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-Bold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypist-BoldOblique.ttf',
#  '/home/claire/.fonts/fonts/UbuntuMono/Ubuntu Mono derivative Powerline Italic.ttf',
#  '/home/claire/.fonts/fonts/Inconsolata/Inconsolata for Powerline.otf',
#  '/usr/share/fonts/truetype/kacst/KacstScreen.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSerif-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf',
#  '/usr/share/fonts/truetype/tlwg/Kinnari-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/takao-mincho/TakaoPMincho.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf',
#  '/home/claire/.fonts/fonts/SourceCodePro/Sauce Code Powerline Medium.otf',
#  '/usr/share/fonts/truetype/takao-gothic/TakaoPGothic.ttf',
#  '/usr/share/fonts/opentype/stix/STIXSizeTwoSym-Regular.otf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-RI.ttf',
#  '/usr/share/fonts/truetype/fonts-guru-extra/Saab.ttf',
#  '/home/claire/.fonts/fonts/Hack/Hack-Italic.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstLetter.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-R.ttf',
#  '/home/claire/.fonts/fonts/Monofur/Monofur for Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/Norasi-Oblique.ttf',
#  '/usr/share/fonts/truetype/tlwg/Norasi.ttf',
#  '/usr/share/fonts/truetype/tlwg/Norasi-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-BI.ttf',
#  '/usr/share/fonts/truetype/tlwg/Garuda-BoldOblique.ttf',
#  '/home/claire/.fonts/fonts/Hack/Hack-Regular.ttf',
#  '/home/claire/.fonts/fonts/DroidSansMono/Droid Sans Mono for Powerline.otf',
#  '/usr/share/fonts/truetype/tlwg/Sawasdee-Bold.ttf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Light for Powerline.ttf',
#  '/usr/share/fonts/opentype/stix/STIXSizeFiveSym-Regular.otf',
#  '/usr/share/fonts/truetype/ttf-khmeros-core/KhmerOSsys.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-M.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstDecorative.ttf',
#  '/home/claire/.fonts/fonts/SourceCodePro/Sauce Code Powerline ExtraLight.otf',
#  '/home/claire/.fonts/fonts/Meslo/Meslo LG M Regular for Powerline.otf',
#  '/home/claire/.fonts/fonts/FiraMono/FuraMono-Bold Powerline.otf',
#  '/usr/share/fonts/truetype/freefont/FreeMonoOblique.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstBook.ttf',
#  '/home/claire/.fonts/fonts/SourceCodePro/Sauce Code Powerline Semibold.otf',
#  '/home/claire/.fonts/fonts/Meslo/Meslo LG L DZ Regular for Powerline.otf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypewriter.ttf',
#  '/home/claire/.fonts/fonts/InconsolataDz/Inconsolata-dz for Powerline.otf',
#  '/home/claire/.fonts/fonts/SourceCodePro/Sauce Code Powerline Black.otf',
#  '/home/claire/.fonts/fonts/DejaVuSansMono/DejaVu Sans Mono Bold for Powerline.ttf',
#  '/home/claire/.fonts/fonts/FiraMono/FuraMono-Medium Powerline.otf',
#  '/usr/share/fonts/truetype/tlwg/Umpush-BoldOblique.ttf',
#  '/usr/share/fonts/opentype/stix/STIXNonUnicode-Regular.otf',
#  '/home/claire/.fonts/fonts/SymbolNeu/Symbol Neu for Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypist.ttf',
#  '/usr/share/fonts/truetype/tlwg/Umpush-LightOblique.ttf',
#  '/usr/share/fonts/truetype/tlwg/Kinnari.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypo-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgMono-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeSans.ttf',
#  '/usr/share/fonts/truetype/tlwg/Loma.ttf',
#  '/usr/share/fonts/truetype/tlwg/Waree-Bold.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstTitle.ttf',
#  '/home/claire/.fonts/fonts/Tinos/Tinos Italic for Powerline.ttf',
#  '/home/claire/.fonts/fonts/FiraMono/FuraMono-Regular Powerline.otf',
#  '/usr/share/fonts/opentype/stix-word/STIX-BoldItalic.otf',
#  '/usr/share/fonts/truetype/takao-gothic/TakaoExGothic.ttf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Thin for Powerline.ttf',
#  '/home/claire/.fonts/fonts/DroidSansMonoSlashed/Droid Sans Mono Slashed for Powerline.ttf',
#  '/usr/share/fonts/truetype/fonts-japanese-gothic.ttf',
#  '/usr/share/fonts/truetype/tlwg/Kinnari-Bold.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeSerif.ttf',
#  '/usr/share/fonts/opentype/stix/STIXSizeFourSym-Regular.otf',
#  '/usr/share/fonts/truetype/sinhala/lklug.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgMono-Oblique.ttf',
#  '/usr/share/fonts/truetype/kacst-one/KacstOne-Bold.ttf',
#  '/home/claire/.fonts/fonts/MuseoSans/MuseoSans_500_Italic.otf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-B.ttf',
#  '/usr/share/fonts/truetype/tlwg/Garuda.ttf',
#  '/usr/share/fonts/truetype/takao-mincho/TakaoExMincho.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstQurn.ttf',
#  '/home/claire/.fonts/fonts/Monofur/Monofur Bold for Powerline.ttf',
#  '/home/claire/.fonts/fonts/Arimo/Arimo for Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/Loma-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/tlwg/Sawasdee-Oblique.ttf',
#  '/home/claire/.fonts/fonts/AnonymousPro/Anonymice Powerline Italic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf',
#  '/usr/share/fonts/opentype/stix/STIXSizeThreeSym-Regular.otf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsUpSm-Regular.otf',
#  '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf',
#  '/usr/share/fonts/opentype/stix-word/STIX-Regular.otf',
#  '/usr/share/fonts/truetype/kacst-one/KacstOne.ttf',
#  '/usr/share/fonts/opentype/stix/STIXVariants-Regular.otf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsUpD-Bold.otf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-L.ttf',
#  '/usr/share/fonts/truetype/tlwg/Kinnari-Italic.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-B.ttf',
#  '/usr/share/fonts/truetype/padauk/Padauk.ttf',
#  '/home/claire/.fonts/fonts/Meslo/Meslo LG S Regular for Powerline.otf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf',
#  '/usr/share/fonts/truetype/tlwg/Laksaman-Bold.ttf',
#  '/usr/share/fonts/truetype/tlwg/Waree-Oblique.ttf',
#  '/home/claire/.fonts/fonts/Arimo/Arimo Bold Italic for Powerline.ttf',
#  '/home/claire/.fonts/fonts/Meslo/Meslo LG S DZ Regular for Powerline.otf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf',
#  '/home/claire/.fonts/fonts/Cousine/Cousine for Powerline.ttf',
#  '/usr/share/fonts/opentype/stix/STIXNonUnicode-Italic.otf',
#  '/usr/share/fonts/truetype/tlwg/Waree-BoldOblique.ttf',
#  '/usr/share/fonts/opentype/stix/STIXGeneral-Italic.otf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Italic for Powerline.ttf',
#  '/usr/share/fonts/truetype/ttf-khmeros-core/KhmerOS.ttf',
#  '/home/claire/.fonts/fonts/Tinos/Tinos for Powerline.ttf',
#  '/usr/share/fonts/opentype/stix/STIXSizeFourSym-Bold.otf',
#  '/usr/share/fonts/opentype/stix-word/STIX-Italic.otf',
#  '/usr/share/fonts/truetype/kacst/mry_KacstQurn.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/UbuntuMono-RI.ttf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsUp-Regular.otf',
#  '/usr/share/fonts/opentype/stix/STIXSizeOneSym-Bold.otf',
#  '/usr/share/fonts/truetype/kacst/KacstOffice.ttf',
#  '/usr/share/fonts/opentype/stix-word/STIXMath-Regular.otf',
#  '/usr/share/fonts/truetype/tlwg/Purisa-Bold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypist-Oblique.ttf',
#  '/home/claire/.fonts/fonts/SourceCodePro/Sauce Code Powerline Light.otf',
#  '/home/claire/.fonts/fonts/Arimo/Arimo Bold for Powerline.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypewriter-BoldOblique.ttf',
#  '/home/claire/.fonts/fonts/Tinos/Tinos Bold Italic for Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/Umpush-Oblique.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypewriter-Oblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf',
#  '/home/claire/.fonts/fonts/DejaVuSansMono/DejaVu Sans Mono Bold Oblique for Powerline.ttf',
#  '/home/claire/.fonts/fonts/UbuntuMono/Ubuntu Mono derivative Powerline.ttf',
#  '/home/claire/.fonts/fonts/AnonymousPro/Anonymice Powerline Bold Italic.ttf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsSm-Regular.otf',
#  '/usr/share/fonts/truetype/fonts-japanese-mincho.ttf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsSm-Bold.otf',
#  '/usr/share/fonts/truetype/kacst/KacstArt.ttf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsD-Bold.otf',
#  '/usr/share/fonts/truetype/freefont/FreeMonoBoldOblique.ttf',
#  '/home/claire/.fonts/fonts/Cousine/Cousine Italic for Powerline.ttf',
#  '/home/claire/.fonts/fonts/DroidSansMonoDotted/Droid Sans Mono Dotted for Powerline.ttf',
#  '/usr/share/fonts/opentype/stix/STIXVariants-Bold.otf',
#  '/usr/share/fonts/truetype/tlwg/Garuda-Oblique.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Medium for Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/Kinnari-BoldOblique.ttf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Light Italic for Powerline.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
#  '/home/claire/.fonts/fonts/Monofur/Monofur Italic for Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/Garuda-Bold.ttf',
#  '/usr/share/fonts/truetype/openoffice/opens___.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypist-Bold.ttf',
#  '/usr/share/fonts/truetype/tibetan-machine/TibetanMachineUni.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeSerifBoldItalic.ttf',
#  '/usr/share/fonts/truetype/tlwg/Purisa.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeSansBold.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeSansOblique.ttf',
#  '/home/claire/.fonts/fonts/Meslo/Meslo LG M DZ Regular for Powerline.otf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-Italic.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-MI.ttf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Medium Italic for Powerline.ttf',
#  '/home/claire/.fonts/fonts/Hack/Hack-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypo.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf',
#  '/usr/share/fonts/truetype/tlwg/Waree.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeMonoBold.ttf',
#  '/usr/share/fonts/opentype/stix/STIXNonUnicode-BoldItalic.otf',
#  '/usr/share/fonts/truetype/takao-gothic/TakaoGothic.ttf',
#  '/usr/share/fonts/truetype/tlwg/Purisa-BoldOblique.ttf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsD-Regular.otf',
#  '/usr/share/fonts/truetype/tlwg/Laksaman-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstDigital.ttf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsUpD-Regular.otf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypo-Bold.ttf',
#  '/home/claire/.fonts/fonts/UbuntuMono/Ubuntu Mono derivative Powerline Bold Italic.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-LI.ttf',
#  '/usr/share/fonts/opentype/stix/STIXSizeOneSym-Regular.otf',
#  '/home/claire/.fonts/fonts/Meslo/Meslo LG L Regular for Powerline.otf',
#  '/home/claire/.fonts/fonts/DejaVuSansMono/DejaVu Sans Mono for Powerline.ttf',
#  '/usr/share/fonts/opentype/stix/STIXIntegralsUp-Bold.otf',
#  '/home/claire/.fonts/fonts/SourceCodePro/Sauce Code Powerline Regular.otf',
#  '/usr/share/fonts/truetype/kacst/KacstPen.ttf',
#  '/home/claire/.fonts/fonts/AnonymousPro/Anonymice Powerline Bold.ttf',
#  '/usr/share/fonts/opentype/stix/STIXGeneral-Regular.otf',
#  '/usr/share/fonts/truetype/ancient-scripts/Symbola_hint.ttf',
#  '/home/claire/.fonts/fonts/AnonymousPro/Anonymice Powerline.ttf',
#  '/home/claire/.fonts/fonts/MuseoSans/MuseoSans_500.otf',
#  '/usr/share/fonts/truetype/padauk/Padauk-bold.ttf',
#  '/home/claire/.fonts/fonts/UbuntuMono/Ubuntu Mono derivative Powerline Bold.ttf',
#  '/usr/share/fonts/truetype/tlwg/Laksaman-Italic.ttf',
#  '/usr/share/fonts/truetype/tlwg/Norasi-Italic.ttf',
#  '/usr/share/fonts/truetype/takao-mincho/TakaoMincho.ttf',
#  '/usr/share/fonts/truetype/tlwg/Sawasdee.ttf',
#  '/usr/share/fonts/truetype/padauk/Padauk-book.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-R.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstNaskh.ttf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Thin Italic for Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/Loma-Bold.ttf',
#  '/home/claire/.fonts/fonts/LiberationMono/Literation Mono Powerline Bold Italic.ttf',
#  '/usr/share/fonts/truetype/tlwg/Umpush-Bold.ttf',
#  '/usr/share/fonts/opentype/stix/STIXSizeThreeSym-Bold.otf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Bold for Powerline.ttf',
#  '/home/claire/.fonts/fonts/LiberationMono/Literation Mono Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/Laksaman.ttf',
#  '/usr/share/fonts/truetype/padauk/Padauk-bookbold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
#  '/usr/share/fonts/opentype/stix/STIXGeneral-Bold.otf',
#  '/usr/share/fonts/truetype/tlwg/Norasi-Bold.ttf',
#  '/usr/share/fonts/truetype/lohit-punjabi/Lohit-Punjabi.ttf',
#  '/usr/share/fonts/truetype/tlwg/Kinnari-Oblique.ttf',
#  '/home/claire/.fonts/fonts/RobotoMono/Roboto Mono Bold Italic for Powerline.ttf',
#  '/home/claire/.fonts/fonts/SourceCodePro/Sauce Code Powerline Bold.otf',
#  '/usr/share/fonts/truetype/abyssinica/AbyssinicaSIL-R.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypo-Oblique.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstFarsi.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeSansBoldOblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeMono.ttf',
#  '/usr/share/fonts/truetype/tlwg/Norasi-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf',
#  '/usr/share/fonts/truetype/ubuntu-font-family/Ubuntu-C.ttf',
#  '/usr/share/fonts/truetype/tlwg/Umpush.ttf',
#  '/usr/share/fonts/truetype/kacst/KacstPoster.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-BoldItalic.ttf',
#  '/home/claire/.fonts/fonts/LiberationMono/Literation Mono Powerline Italic.ttf',
#  '/home/claire/.fonts/fonts/DejaVuSansMono/DejaVu Sans Mono Oblique for Powerline.ttf',
#  '/usr/share/fonts/truetype/tlwg/Purisa-Oblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgTypewriter-Bold.ttf',
#  '/home/claire/.fonts/fonts/Inconsolata-g/Inconsolata-g for Powerline.otf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/freefont/FreeSerifBold.ttf',
#  '/home/claire/.fonts/fonts/Tinos/Tinos Bold for Powerline.ttf',
#  '/usr/share/fonts/opentype/stix/STIXSizeTwoSym-Bold.otf',
#  '/usr/share/fonts/opentype/stix/STIXNonUnicode-Bold.otf',
#  '/usr/share/fonts/truetype/tlwg/Umpush-Light.ttf',
#  '/usr/share/fonts/truetype/tlwg/Sawasdee-BoldOblique.ttf',
#  '/home/claire/.fonts/fonts/Cousine/Cousine Bold Italic for Powerline.ttf',
#  '/usr/share/fonts/opentype/stix/STIXGeneral-BoldItalic.otf',
#  '/usr/share/fonts/opentype/stix-word/STIX-Bold.otf',
#  '/usr/share/fonts/truetype/tlwg/TlwgMono.ttf',
#  '/usr/share/fonts/truetype/tlwg/TlwgMono-Bold.ttf',
#  '/home/claire/.fonts/fonts/LiberationMono/Literation Mono Powerline Bold.ttf',
#  '/usr/share/fonts/truetype/tlwg/Loma-Oblique.ttf']

# %% [markdown]
# ## LaTeX support

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare a curve of square numbers
x = np.linspace(0,200,100) # Prepare 100 evenly spaced numbers from 0 to
200
y1 = x # Prepare an array of y equals to x squared
y2 = x+20
# Plot a curve of square numbers
plt.plot(x,y1,label = '$x$')
plt.plot(x,y2,label = r'$x^2+\alpha$')
plt.legend()
plt.show()

# %% [markdown]
# ___
# # Customizing lines and markers

# %% [markdown]
# ## Lines

# %%
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()

# Prepare 100 evenly spaced numbers from 0 to 200
evens = np.linspace(0,200,100)
# Plot a curve of square numbers
plt.plot(evens,evens**2,label = '$x^2$',c='burlywood',ls=('dashed'),lw=2)
plt.legend()
plt.savefig('images/B07915_02_burlywooddash.png',dpi=300)
plt.show()

# %% [markdown]
# ### Setting capstyle of dashes

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare 6 lines
x = np.linspace(0,200,100)
y1 = x*0.5
y2 = x
y3 = x*2
y4 = x*3
y5 = x*4
y6 = x*5
# Plot lines with different dash cap styles
plt.plot(x,y1,label = '0.5x', lw=5, ls=':',dash_capstyle='butt')
plt.plot(x,y2,label = 'x', lw=5, ls='--',dash_capstyle='butt')
plt.plot(x,y3,label = '2x', lw=5, ls=':',dash_capstyle='projecting')
plt.plot(x,y4,label = '3x', lw=5, ls='--',dash_capstyle='projecting')
plt.plot(x,y5,label = '4x', lw=5, ls=':',dash_capstyle='round')
plt.plot(x,y6,label = '5x', lw=5, ls='--',dash_capstyle='round')
plt.show()

# %% [markdown]
# ### Advanced example

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare 100 evenly spaced numbers from 0 to 200
x = np.linspace(0,200,100)
# Plot lines with different line styles
plt.plot(x,x*2,label = '2x', lw=2, ls=(0,(1,1)))
plt.plot(x,x*3,label = '3x', lw=2, ls=(0,(5,3,1,3,1,3)))
plt.plot(x,x*4,label = '4x', lw=2, ls=(3,(5,5)))
plt.plot(x,x*5,label = '5x', lw=2, ls=(2,(5,2,1,2)))
plt.savefig('images/B07915_02_dashdemo.png',dpi=300)
plt.show()

# %% [markdown]
# ## Markers

# %% [markdown]
# ### Choosing markers

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# Prepare 100 random numbers to plot
x = np.random.rand(100)
y = np.random.rand(100)

# Prepare 100 random numbers within the range of the number of available markers as index
# Each random number will serve as the choice of marker of the corresponding coordinates
markerindex = np.random.randint(0, len(Line2D.markers), 100)

# Plot all kinds of available markers at random coordinates 
# for each type of marker, plot a point at the above generated random coordinates with the marker type
for k, m in enumerate(Line2D.markers):
    i = (markerindex == k)
    plt.scatter(x[i], y[i], marker=m)
plt.show()

# %% [markdown]
# ### Adjusting marker sizes

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# Prepare 5 lines
x = np.linspace(0,20,10)
y1 = x
y2 = x*2
y3 = x*3
y4 = x*4
y5 = x*5
# Plot lines with different marker sizes
plt.plot(x,y1,label = 'x', lw=2, marker='s', ms=10)  # square size 10
plt.plot(x,y2,label = '2x', lw=2, marker='^', ms=12) # triangle size 12
plt.plot(x,y3,label = '3x', lw=2, marker='o', ms=10) # circle size 10
plt.plot(x,y4,label = '4x', lw=2, marker='D', ms=8)  # diamond size 8
plt.plot(x,y5,label = '5x', lw=2, marker='P', ms=12) # filled plus sign size 12

# get current axes and store it to ax
ax = plt.gca()
plt.show()

# %% [markdown]
# ___
# # Customizing grids, ticks and axes

# %% [markdown]
# ## Grids

# %% [markdown]
# ### Adding grids
# Sometimes it may not be easy to tell the coordinates of any point in the plot. Grid lines that extend from axis tick marks help us estimate the values at a certain position. Grids can be added by calling `pyplot.grid()`. By default, grid lines will be added at major tick marks. As in other line features, `pyplot.grid()` takes in parameters such as linewidth (lw), linestyle (ls) andn color (c).
# //Insert image

# %%
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()

# Prepare 100 evenly spaced numbers from 0 to 200
evens = np.linspace(0,200,100)
plt.plot(evens,evens**2,label = '$x^2$') # LaTex Math notation support for x squared
plt.grid()
plt.legend()
plt.savefig('images/B07915_02_defaultgrid.png',dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare 100 evenly spaced numbers from 0 to 200
evens = np.linspace(0,200,100)
plt.plot(evens,evens**2,label = '$x^2$') # LaTex Math notation support for x squared
plt.grid(color='lightblue', linestyle='-.', linewidth=0.6)
plt.legend()
plt.savefig('images/B07915_02_lightbluegrid.png',dpi=300)
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ## Ticks

# %% [markdown]
# ### Setting label sizes

# %%
import matplotlib.pyplot as plt
# Facebook emoji copied from http://emojipedia.org/facebook/
tick_labels = ['❤','😂','😲','😢','😠']
y = [24,12,16,2,1]
x = range(5)
plt.bar(x, y, tick_label=tick_labels, align='center',facecolor='#3b5998')

# Get the current axes
ax = plt.gca()
# Set label size
ax.xaxis.set_tick_params(labelsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Trying out the ticker locator and formatter

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
"""
Number for Netflix streaming subscribers from 2012-2017
[ 30 ]Figure Aesthetics
Data were obtained from Statista on
https://www.statista.com/statistics/250934/quarterly-number-of-netflix-stre
aming-subscribers-worldwide/ on May 10, 2017. The data were originally
published by Netflix in April 2017.
"""
# Prepare the data set
x = range(2011,2018)
y = [26.48,27.56,29.41,33.27,36.32,37.55,40.28,44.35,48.36,50.05,53.06,57.39,\
     62.27,65.55,69.17,74.76,81.5,83.18,86.74,93.8,98.75] # quarterly subscriber count in millions
# Plot lines with different line styles
plt.plot(y,'^',label = 'Netflix subscribers',ls='-')
# get current axes and store it to ax
ax = plt.gca()
# set ticks in multiples for both labels
ax.xaxis.set_major_locator(ticker.MultipleLocator(4)) # set major marks every 4 quarters, ie once a year
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1)) # set minor marks for each quarter
ax.yaxis.set_major_locator(ticker.MultipleLocator(10)) 
ax.yaxis.set_minor_locator(ticker.MultipleLocator(2))
# label the start of each year by FixedFormatter
ax.get_xaxis().set_major_formatter(ticker.FixedFormatter(x))
plt.legend()
plt.show()

# %% [markdown]
# ### Rotating tick labels

# %%
import matplotlib.pyplot as plt
import numpy as np

techs = ['Google Adsense','DoubleClick.Net','Facebook Custom Audiences','Google Publisher Tag', 'App Nexus']
y_pos = np.arange(len(techs))
# Number of websites using the advertising technologies
# Data were quoted from builtwith.com on May 8th 2017
websites = [14409195,1821385,948344,176310,283766]
plt.bar(y_pos, websites, align='center', alpha=0.5)
# set x-axis tick rotation
plt.xticks(y_pos, techs, rotation=25)
plt.ylabel('Live site count')
plt.title('Online advertising technologies usage')
plt.show()

# %% [markdown]
# ## Axes

# %% [markdown]
# ## Nonlinear axes

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare 100 evenly spaced numbers from 0 to 200
x = np.linspace(0, 200, 100)
y = x * 2
plt.figure()
plt.plot(x,y)

# Plot an outlier point
plt.plot([100], [100000], 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Logarithmic scale

# %%
plt.figure()

plt.plot(x,y)
# Plot an outlier point
plt.plot([100], [100000], 'o')

plt.xlabel('x')
plt.ylabel('y')

#Change y-axis to log10 scale
plt.yscale('log')

plt.show()

# %% [markdown]
# ### Changing the base of log scale

# %%
plt.figure()

plt.plot(x,y)
# Plot an outlier point
plt.plot([100], [100000], 'o')

plt.xlabel('x')
plt.ylabel('y')

#Change y-axis to log2 scale
plt.yscale('log', basey=2)

plt.show()

# %% [markdown]
# #### Advanced example

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

def ticks(y, pos):
    """ Method that formats the axis labels to natural log scale 
    """
    
    # Use Python string formatter to limit the number of decimal places for float values. 
    # The precision of the formatted float value can be specified using a full stop, followed 
    # by the number of decimal places you would like to include.
    #
    # Latex notation is denoted by $$ in Matplotlib.
    # The outer double curly braces {{ }} will be escaped by Python to {}, while the innermost
    # curly braces contains the actual Python float format string. As an example, 7.389 will
    # be converted to $e^{2}$ in latex notation.
    return r'$e^{{{:.0f}}}$'.format(np.log(y))


x = np.linspace(0, 200, 100)
y = x * 2

plt.figure()

# The two keyword arguments, basex and basey, can be specified together in plt.loglog(). 
# Note: natural log scale is used on the y axis by supplying numpy.e to basey
plt.loglog(x,y, basex=2, basey=np.e)

# Plot an outlier point
plt.plot([100], [100000], 'o')

# Get the current axes in this plot
ax = plt.gca()
# Apply the tick formatter to the y-axis
ax.yaxis.set_major_formatter(FuncFormatter(ticks))

plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# ## Symmetrical logarithmic scale

# %% [markdown]
# The base a logarithm of a negative number is undefined. If we try to supply non-positive numbers (≤0) to numpy.log(), we see the following errors:

# %%
np.log(0)
# Output: -inf

np.log(-1)
# Output: nan
# Out:
# /home/claire/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /home/claire/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log
#   after removing the cwd from sys.path.
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare 100 evenly spaced numbers from -200 to 200
x = np.linspace(-200, 200, 100)
y = x * 2

# Setup subplot with 3 rows and 2 columns, with shared x-axis.
# More details about subplots will be discussed in Chapter 3.
f, axarr = plt.subplots(nrows=3, ncols=2, figsize=(8,10), sharex=True)

# Linear scale
axarr[0, 0].plot(x, y)
axarr[0, 0].plot([-200,200], [10,10]) # Horizontal line (y=10)
axarr[0, 0].set_title('Linear scale')

# Log scale, mask non-positive numbers
axarr[0, 1].plot(x,y)
axarr[0, 1].plot([-200,200], [10,10])
axarr[0, 1].set_title('Log scale, nonposy=mask')
axarr[0, 1].set_yscale('log', nonposy='mask') # Note: axes object requires set_yscale instead of yscale method.

# Log scale, clip non-positive numbers
axarr[1, 0].plot(x,y)
axarr[1, 0].plot([-200,200], [10,10])
axarr[1, 0].set_title('Log scale, nonposy=clip')
axarr[1, 0].set_yscale('log', nonposy='clip')

# Symlog scale
axarr[1, 1].plot(x,y)
axarr[1, 1].plot([-200,200], [10,10])
axarr[1, 1].set_title('Symlog scale')
axarr[1, 1].set_yscale('symlog')

# Symlog scale, expand the linear range to -50,50 (default=None)
axarr[2, 0].plot(x,y)
axarr[2, 0].plot([-200,200], [10,10])
axarr[2, 0].set_title('Symlog scale, linthreshy=50')
axarr[2, 0].set_yscale('symlog', linthreshy=50)

# Symlog scale, expand the linear scale to 3 (default=1)
# The linear region is expanded, while the log region is compressed.
axarr[2, 1].plot(x,y)
axarr[2, 1].plot([-200,200], [10,10])
axarr[2, 1].set_title('Symlog scale, linscaley=3')
axarr[2, 1].set_yscale('symlog', linscaley=3)

plt.show()

# %% [markdown]
# ## Logit scale

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare 1000 sorted random numbers from the normal distribution
np.random.seed(1)
y = np.random.normal(0.5, 0.1, 1000)
y.sort()
x = np.arange(len(y))
plt.figure()
plt.plot(x,y)

# Transform x-axis to logit scale
plt.yscale('logit')
plt.show()

# %% [markdown]
# ___
# # Using style sheet

# %%
import matplotlib as mpl
mpl.style.available # check the available stylesheets
# Out:
# ['seaborn-ticks',
#  'ggplot',
#  'seaborn',
#  'dark_background',
#  'bmh',
#  'seaborn-poster',
#  'seaborn-whitegrid',
#  'seaborn-darkgrid',
#  'fivethirtyeight',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-notebook',
#  'grayscale',
#  'seaborn-white',
#  '_classic_test',
#  'seaborn-muted',
#  'seaborn-paper',
#  'seaborn-talk',
#  'seaborn-deep',
#  'seaborn-dark-palette',
#  'seaborn-pastel',
#  'classic']

# %% [markdown]
# ## Applying a stylesheet

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
# set the style as 'bmh'
mpl.style.use('bmh')
months = ['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']
y_pos = np.arange(len(months))
# 2016 Hong Kong monthly mean temperature
# Data were quoted from Hong Kong Observatory data on May 8th 2017
# http://www.hko.gov.hk/wxinfo/pastwx/2016/ywx2016.htm
meantemp = [16.,15.5,17.5,23.6,26.7,29.4,29.8,28.4,27.9,26.8,22.3,19.6]
plt.bar(y_pos, meantemp, align='center', alpha=0.5)
plt.xticks(y_pos, months)
plt.ylabel('Temperature (ºC)')
plt.title('Hong Kong 2016 monthly mean temperature')
plt.show()

# %% [markdown]
# ## Resetting to default styles

# %%
plt.rcdefaults()

# %%
# alternate method to reset to default parameters
import matplotlib as mpl 
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ___
# # Titles and legends

# %% [markdown]
# ## Test your skills

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np 
import matplotlib as mpl

mpl.style.use('seaborn-darkgrid')

# 2001-2015 per genome sequencing cost in USD
# Adapted from NIH National Human Genome Research Institute figures
# genome.gov/sequencingcosts
# Data were quoted from builtwith.com on May 8th 2017
# Seasonal data were averaged by year for simplicity

# Prepare the data
years = list(range(2001,2016))
y_pos = np.arange(len(years)) 
seqcost = [95263071.92,70175437.42,61448421.50,53751684.08,40157554.23,28780376.21,\
 20442576.14,19934345.74,18519312.16,17534969.56,16159699.44,16180224.10,\
 13801124.19,12585658.90,11732534.52,11455315.22,10474556.36,9408738.91,\
 9047002.97,8927342.14,7147571.39,3063819.99,1352982.23,752079.90,342502.06,\
 232735.44,154713.60,108065.14,70333.33,46774.27,31512.04,31124.96,29091.73,\
 20962.78,16712.01,10496.93,7743.44,7666.22,5901.29,5984.72,6618.35,5671.35,\
 5826.26,5550.26,5096.08,4008.11,4920.50,4904.85,5730.89,3969.84,4210.79,1363.24,1245.00]

# Plot the data
plt.plot(seqcost,marker='D',ms=3,color='navy',label='Genome sequencing cost') 
plt.xticks(y_pos, years) 

# Set logarithmic scale on y-axis
plt.yscale('log')
plt.title('2001-2015 per Genome Sequencing Cost',color='darkblue',fontweight='semibold') 
plt.legend()

# Get current axes
ax = plt.gca()

# Set ticks in multiples for x-axis
ax.xaxis.set_major_locator(ticker.MultipleLocator(4))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))

# label the start of each year by FixedFormatter
ax.get_xaxis().set_major_formatter(ticker.FixedFormatter(years))

# Label the axes
ax.set_xlabel('Year')
ax.set_ylabel('Per Genome Sequencing Cost (USD)')

ax.xaxis.set_tick_params(labelsize=10)

plt.show()
