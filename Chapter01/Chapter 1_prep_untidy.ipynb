# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print('Hello Plots!')
# Out:
# Hello Plots!

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (20 * np.random.rand(N))**2

plt.scatter(x, y, s=area, c=colors, alpha=np.random.rand()*0.5)
plt.show()

# %%
import matplotlib as mpl

# %%
mpl.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn']

# %%
N = 30

np.random.seed(42)
x1 = np.random.rand(N)
y1 = np.random.rand(N)

np.random.seed(24)
x2 = np.random.rand(N)
y2 = np.random.rand(N)

plt.scatter(x1, y1)
plt.scatter(x2, y2)
plt.show()

# %%
N = 30
mpl.style.use('classic')
np.random.seed(42)
x1 = np.random.rand(N)
y1 = np.random.rand(N)


np.random.seed(24)
x2 = np.random.rand(N)
y2 = np.random.rand(N)

plt.scatter(x1, y1,label='a')
plt.scatter(x2, y2,label='b')
plt.legend()
plt.show()

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
N = 30
np.random.seed(42)
x1 = np.random.rand(N)
y1 = np.random.rand(N)


np.random.seed(24)
x2 = np.random.rand(N)
y2 = np.random.rand(N)

plt.scatter(x1, y1,label='a')
plt.scatter(x2, y2,label='b')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = M = 200
X, Y = np.ogrid[0:20:N*1j, 0:20:M*1j]
data = np.sin(np.pi * X*2 / 20) * np.cos(np.pi * Y*2 / 20)

fig, (ax2, ax1) = plt.subplots(1, 2, figsize=(7, 3))
im = ax1.imshow(data, extent=[0, 200, 0, 200])
ax1.set_title("v2.0: 'viridis'")
fig.colorbar(im, ax=ax1, shrink=0.8)

im2 = ax2.imshow(data, extent=[0, 200, 0, 200], cmap='jet')
fig.colorbar(im2, ax=ax2, shrink=0.8)
ax2.set_title("classic: 'jet'")

fig.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = M = 200
X, Y = np.ogrid[0:20:N*1j, 0:20:M*1j]
data = np.sin(np.pi * X*2 / 2000) * np.cos(np.pi * Y*2 / 10)

fig, (ax2, ax1) = plt.subplots(1, 2, figsize=(7, 3))
im = ax1.imshow(data, extent=[0, 200, 0, 200])
ax1.set_title("v2.0: 'viridis'")
fig.colorbar(im, ax=ax1, shrink=0.8)

im2 = ax2.imshow(data, extent=[0, 200, 0, 200], cmap='jet')
fig.colorbar(im2, ax=ax2, shrink=0.8)
ax2.set_title("classic: 'jet'")

#fig.tight_layout()
plt.tight_layout()
#plt.show()

# %%
list(mpl.rcParams['axes.prop_cycle'])
# Out:
# [{'color': '#1f77b4'},
#  {'color': '#ff7f0e'},
#  {'color': '#2ca02c'},
#  {'color': '#d62728'},
#  {'color': '#9467bd'},
#  {'color': '#8c564b'},
#  {'color': '#e377c2'},
#  {'color': '#7f7f7f'},
#  {'color': '#bcbd22'},
#  {'color': '#17becf'}]

# %%
'#1f77b4'

# %%
import os, sys
os.path.dirname(sys.executable)
# Out:
# 'c:\\users\\claire\\appdata\\local\\programs\\python\\python36'

# %%
# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause


import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
Y = iris.target

x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5

plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())

# To getter a better understanding of interaction of the dimensions
# plot the first three PCA dimensions
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=Y,
           cmap=plt.cm.Paired)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-444b9f2d2bae> in <module>()
#       5 import matplotlib.pyplot as plt
#       6 from mpl_toolkits.mplot3d import Axes3D
# ----> 7 from sklearn import datasets
#       8 from sklearn.decomposition import PCA
#       9
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import matplotlib.pyplot as plt
# Set the random seed for consistency
np.random.seed(12)

fig, ax = plt.subplots(1)

# Show the whole color range
for i in range(8):
    x = np.random.normal(loc=i, size=1000)
    y = np.random.normal(loc=i, size=1000)
    ax.scatter(x, y, label=str(i))
ax.legend()

# %%
# https://software-carpentry.org/blog/2012/05/an-exercise-with-matplotlib-and-numpy.html
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import os

event_types = ['Rain', 'Thunderstorm', 'Snow', 'Fog']
num_events = len(event_types)

def event2int(event):
    return event_types.index(event)

def date2int(date_str):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    return date.toordinal()

def r_squared(actual, ideal):
    actual_mean = np.mean(actual)
    ideal_dev = np.sum([(val - actual_mean)**2 for val in ideal])
    actual_dev = np.sum([(val - actual_mean)**2 for val in actual])

    return ideal_dev / actual_dev

def read_weather(file_name):
    dtypes = np.dtype({ 'names' : ('timestamp', 'max temp', 'mean temp', 'min temp', 'events'),
                        'formats' : [np.int, np.float, np.float, np.float, 'S100'] })

    data = np.loadtxt(file_name, delimiter=',', skiprows=1,
            converters = { 0 : date2int },
            usecols=(0,1,2,3,21), dtype=dtypes)

    return data
def temp_plot(dates, mean_temps):

    year_start = datetime(2012, 1, 1)
    days = [(d - year_start).days + 1 for d in dates]

    fig = pyplot.figure()
    pyplot.title('Temperatures in Bloomington 2012')
    pyplot.ylabel('Mean Temperature (F)')
    pyplot.xlabel('Day of Year')

    pyplot.plot(days, mean_temps, marker='o')

    return fig

# %%
data = read_weather('data/weather.csv')
min_temps = data['min temp']
mean_temps = data['mean temp']
max_temps = data['max temp']
dates = [datetime.fromordinal(d) for d in data['timestamp']]
events = data['events']

if not os.path.exists('plots'):
    os.mkdir('plots')

fig = temp_plot(dates, mean_temps)
fig.savefig('plots/day_vs_temp.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-5d585d4a3f21> in <module>()
# ----> 1 data = read_weather('data/weather.csv')
#       2 min_temps = data['min temp']
#       3 mean_temps = data['mean temp']
#       4 max_temps = data['max temp']
#       5 dates = [datetime.fromordinal(d) for d in data['timestamp']]
#
# <ipython-input-10-a327fd73016b> in read_weather(file_name)
#       5     data = np.loadtxt(file_name, delimiter=',', skiprows=1,
#       6             converters = { 0 : date2int },
# ----> 7             usecols=(0,1,2,3,21), dtype=dtypes)
#       8
#       9     return data
#
# c:\users\claire\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     858                 fh = iter(open(fname, 'U'))
#     859             else:
# --> 860                 fh = iter(open(fname))
#     861         else:
#     862             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/weather.csv'

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
a = np.arange(20)
plt.plot(a,a**2,label = 'log')
plt.legend()
plt.show()

# %%
mpl.style.use('classic')
a = np.arange(20)
plt.plot(a,a**2,label = 'log')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
# facebook emoji copied from http://emojipedia.org/facebook/
import matplotlib.pyplot as plt
mpl.rcParams.update(mpl.rcParamsDefault)

fig, ax = plt.subplots()
tick_labels = [ '❤️', '😂', '😯', '😢', '😡'] # cannot show '👍'

y = [24,12,16,2,1]
x = range(5)
ax.bar(x, y, tick_label=tick_labels, align='center',facecolor='#3b5998')
ax.xaxis.set_tick_params(labelsize=36)

ax.set_title('эмоции-реакции в Facebook')

# %%
# facebook emoji copied from http://emojipedia.org/facebook/
import matplotlib.pyplot as plt

mpl.style.use('classic')
fig, ax = plt.subplots()
tick_labels = ['👍', '❤️', '😂', '😯', '😢', '😡']

y = [42,24,12,16,2,1]
x = range(6)
ax.bar(x, y, tick_label=tick_labels, align='center',facecolor='#3b5998')
ax.xaxis.set_tick_params(labelsize=20)

ax.set_title('эмоции-реакции в Facebook')
plt.show()

# %%
mpl.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# ['c:\\windows\\fonts\\tektonpro-boldext.otf',
#  'c:\\windows\\fonts\\comicbd.ttf',
#  'C:\\Windows\\Fonts\\ChaparralPro-Italic.otf',
#  'C:\\Windows\\Fonts\\ALGER.TTF',
#  'C:\\Windows\\Fonts\\Raleway-ThinItalic.ttf',
#  'C:\\Windows\\Fonts\\mangal.ttf',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\ERASLGHT.TTF',
#  'c:\\windows\\fonts\\sauce code powerline extralight.otf',
#  'C:\\Windows\\Fonts\\PARCHM.TTF',
#  'c:\\windows\\fonts\\robotocondensed-bolditalic_0.ttf',
#  'C:\\Windows\\Fonts\\upckl.ttf',
#  'C:\\Windows\\Fonts\\GARABD.TTF',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\Windows\\Fonts\\DroidSerif-Regular.ttf',
#  'c:\\windows\\fonts\\comic.ttf',
#  'c:\\windows\\fonts\\kozminpr6n-heavy.otf',
#  'c:\\windows\\fonts\\msyh.ttf',
#  'C:\\Windows\\Fonts\\simpfxo.ttf',
#  'C:\\Windows\\Fonts\\MyriadHebrew-BoldIt.otf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\KozGoPr6N-ExtraLight.otf',
#  'C:\\Windows\\Fonts\\browai.ttf',
#  'C:\\Windows\\Fonts\\TrajanPro-Bold.otf',
#  'C:\\Windows\\Fonts\\MinionPro-Medium.otf',
#  'c:\\windows\\fonts\\notoserif-regular.ttf',
#  'c:\\windows\\fonts\\mriamc.ttf',
#  'c:\\windows\\fonts\\myriadpro-boldcond.otf',
#  'c:\\windows\\fonts\\raleway-extralightitalic.ttf',
#  'C:\\Windows\\Fonts\\CALIST.TTF',
#  'c:\\windows\\fonts\\kalinga.ttf',
#  'c:\\windows\\fonts\\poorich.ttf',
#  'c:\\windows\\fonts\\cordiaz.ttf',
#  'C:\\Windows\\Fonts\\MAIAN.TTF',
#  'C:\\Windows\\Fonts\\upcfi.ttf',
#  'c:\\windows\\fonts\\roboto-mediumitalic_0.ttf',
#  'c:\\windows\\fonts\\htowert.ttf',
#  'C:\\Windows\\Fonts\\upcjbi.ttf',
#  'C:\\Windows\\Fonts\\TektonPro-Bold.otf',
#  'C:\\Windows\\Fonts\\Roboto-Bold.ttf',
#  'c:\\windows\\fonts\\upceb.ttf',
#  'C:\\Windows\\Fonts\\OLDENGL.TTF',
#  'c:\\windows\\fonts\\myriadpro-semibold.otf',
#  'c:\\windows\\fonts\\higashiome-gothic-1.3i_0.ttf',
#  'c:\\windows\\fonts\\kokilai.ttf',
#  'c:\\windows\\fonts\\shonarb.ttf',
#  'C:\\Windows\\Fonts\\RobotoCondensed-Bold.ttf',
#  'c:\\windows\\fonts\\kokilabi.ttf',
#  'C:\\Windows\\Fonts\\arabtype.ttf',
#  'c:\\windows\\fonts\\bonvenocf-light.otf',
#  'c:\\windows\\fonts\\magnetob.ttf',
#  'C:\\Windows\\Fonts\\Raleway-MediumItalic.ttf',
#  'c:\\windows\\fonts\\gilsanub.ttf',
#  'C:\\Windows\\Fonts\\Shonar.ttf',
#  'c:\\windows\\fonts\\antquab.ttf',
#  'C:\\Windows\\Fonts\\upcfl.ttf',
#  'C:\\Windows\\Fonts\\Existence-StencilLight.otf',
#  'c:\\windows\\fonts\\laouib.ttf',
#  'C:\\Windows\\Fonts\\davidbd.ttf',
#  'C:\\Windows\\Fonts\\ERASMD.TTF',
#  'C:\\Windows\\Fonts\\angsaub.ttf',
#  'c:\\windows\\fonts\\robotocondensed-italic_0.ttf',
#  'c:\\windows\\fonts\\tcm_____.ttf',
#  'c:\\windows\\fonts\\corbelb.ttf',
#  'c:\\windows\\fonts\\existence-light.otf',
#  'c:\\program files (x86)\\adobe\\acrobat 2015\\resource\\font\\adobedevanagari-bold.otf',
#  'c:\\windows\\fonts\\itcblkad.ttf',
#  'C:\\Windows\\Fonts\\cordiaui.ttf',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\ROCK.TTF',
#  'C:\\Windows\\Fonts\\ChaparralPro-Bold.otf',
#  'C:\\Windows\\Fonts\\Raleway-SemiBold.ttf',
#  'c:\\windows\\fonts\\centaur.ttf',
#  'c:\\windows\\fonts\\upcdl.ttf',
#  'c:\\windows\\fonts\\raleway-blackitalic.ttf',
#  'C:\\Windows\\Fonts\\LetterGothicStd.otf',
#  'c:\\windows\\fonts\\vani.ttf',
#  'c:\\windows\\fonts\\candarab.ttf',
#  'c:\\windows\\fonts\\hatten.ttf',
#  'C:\\Windows\\Fonts\\NotoSansCJKtc-Bold.otf',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\MSUIGHUR.TTF',
#  'C:\\Windows\\Fonts\\LTYPEO.TTF',
#  'C:\\Windows\\Fonts\\NotoSansCJKtc-Thin.otf',
#  'C:\\Windows\\Fonts\\Philosopher-Regular.ttf',
#  'c:\\windows\\fonts\\vijaya.ttf',
#  'C:\\Windows\\Fonts\\KhmerUI.ttf',
#  'C:\\Windows\\Fonts\\BOOKOSI.TTF',
#  'C:\\Windows\\Fonts\\Existence-Light.otf',
#  'C:\\Windows\\Fonts\\Raleway-Medium.ttf',
#  'c:\\windows\\fonts\\courbi.ttf',
#  'C:\\Windows\\Fonts\\LithosPro-Black.otf',
#  'C:\\Windows\\Fonts\\NuevaStd-Cond.otf',
#  'C:\\Windows\\Fonts\\Raleway-BlackItalic.ttf',
#  'C:\\Windows\\Fonts\\Roboto-ThinItalic_0.ttf',
#  'c:\\windows\\fonts\\tektonpro-boldcond.otf',
#  'c:\\windows\\fonts\\gisha.ttf',
#  'c:\\windows\\fonts\\juice___.ttf',
#  'c:\\windows\\fonts\\kozgopr6n-extralight.otf',
#  'C:\\Windows\\Fonts\\segoeuii.ttf',
#  'C:\\Windows\\Fonts\\comicbd.ttf',
#  'c:\\windows\\fonts\\micross.ttf',
#  'c:\\windows\\fonts\\per_____.ttf',
#  'C:\\Windows\\Fonts\\verdana.ttf',
#  'c:\\windows\\fonts\\webdings.ttf',
#  'C:\\Windows\\Fonts\\BlackoakStd.otf',
#  'c:\\windows\\fonts\\adobearabic-italic.otf',
#  'c:\\windows\\fonts\\myriadpro-it.otf',
#  'c:\\windows\\fonts\\notosanscjktc-demilight.otf',
#  'c:\\windows\\fonts\\kozminpro-medium.otf',
#  'c:\\windows\\fonts\\kozgopro-bold.otf',
#  'C:\\Windows\\Fonts\\browau.ttf',
#  'c:\\windows\\fonts\\consolaz.ttf',
#  'c:\\windows\\fonts\\upcib.ttf',
#  'C:\\Windows\\Fonts\\TektonPro-BoldExt.otf',
#  'C:\\Windows\\Fonts\\Raleway-Italic.ttf',
#  'C:\\Windows\\Fonts\\vrindab.ttf',
#  'c:\\windows\\fonts\\vanilladaisy-pro.otf',
#  'C:\\Windows\\Fonts\\FRABK.TTF',
#  'c:\\windows\\fonts\\kozgopr6n-bold.otf',
#  'c:\\windows\\fonts\\philosopher-bold.ttf',
#  'C:\\Windows\\Fonts\\GOTHICI.TTF',
#  'c:\\windows\\fonts\\bod_r.ttf',
#  'C:\\Windows\\Fonts\\ITCBLKAD.TTF',
#  'c:\\windows\\fonts\\calibril.ttf',
#  'c:\\windows\\fonts\\minionpro-boldit.otf',
#  'c:\\windows\\fonts\\minionpro-semibold.otf',
#  'c:\\windows\\fonts\\arialbi.ttf',
#  'c:\\windows\\fonts\\gara.ttf',
#  'C:\\Windows\\Fonts\\kalinga.ttf',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\pala.ttf',
#  'C:\\Windows\\Fonts\\utsaahb.ttf',
#  'C:\\Windows\\Fonts\\calibril.ttf',
#  'c:\\windows\\fonts\\comfortaa_bold.ttf',
#  'C:\\Windows\\Fonts\\BirchStd.otf',
#  'c:\\windows\\fonts\\lbrite.ttf',
#  'c:\\windows\\fonts\\raleway-lightitalic.ttf',
#  'c:\\windows\\fonts\\roboto-lightitalic_0.ttf',
#  'C:\\Windows\\Fonts\\KozMinPro-Light.otf',
#  'C:\\Windows\\Fonts\\CHILLER.TTF',
#  'C:\\Windows\\Fonts\\IMPRISHA.TTF',
#  'c:\\windows\\fonts\\timesbd.ttf',
#  'c:\\windows\\fonts\\dancing script.ttf',
#  'C:\\Windows\\Fonts\\GOUDOS.TTF',
#  'c:\\windows\\fonts\\khmeruib.ttf',
#  'c:\\windows\\fonts\\dejavusanscondensed-bold.ttf',
#  'c:\\windows\\fonts\\adobearabic-bold.otf',
#  'c:\\windows\\fonts\\bookosi.ttf',
#  'c:\\windows\\fonts\\vanilladaisy-ss06.ttf',
#  'C:\\Windows\\Fonts\\BRLNSB.TTF',
#  'C:\\Windows\\Fonts\\LaoUI.ttf',
#  'C:\\Windows\\Fonts\\aparaji.ttf',
#  'C:\\Windows\\Fonts\\SourceCodePro-Bold.ttf',
#  'C:\\Windows\\Fonts\\FRAMDCN.TTF',
#  'C:\\Windows\\Fonts\\RobotoCondensed-BoldItalic_0.ttf',
#  'c:\\windows\\fonts\\vanilladaisy-ss04.ttf',
#  'C:\\Windows\\Fonts\\RAGE.TTF',
#  'c:\\windows\\fonts\\wingdng2.ttf',
#  'C:\\Windows\\Fonts\\Roboto-Black_0.ttf',
#  'C:\\Windows\\Fonts\\daunpenh.ttf',
#  'c:\\windows\\fonts\\ocrb.ttf',
#  'c:\\windows\\fonts\\msyhbd.ttf',
#  'C:\\Windows\\Fonts\\TektonPro-BoldCond.otf',
#  'c:\\windows\\fonts\\upcjb.ttf',
#  'C:\\Windows\\Fonts\\JUICE___.TTF',
#  'c:\\windows\\fonts\\raavib.ttf',
#  'C:\\Windows\\Fonts\\LetterGothicStd-Slanted.otf',
#  'c:\\windows\\fonts\\poplarstd.otf',
#  'C:\\Windows\\Fonts\\VanillaDaisy-Pro.otf',
#  'C:\\Windows\\Fonts\\simhei.ttf',
#  'C:\\Windows\\Fonts\\GOTHICB.TTF',
#  'C:\\Windows\\Fonts\\msjh.ttf',
#  'C:\\Windows\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\upcibi.ttf',
#  'c:\\windows\\fonts\\angsaz.ttf',
#  'C:\\Windows\\Fonts\\LSANSI.TTF',
#  'C:\\Windows\\Fonts\\ENGR.TTF',
#  'C:\\Windows\\Fonts\\AdobeFanHeitiStd-Bold.otf',
#  'C:\\Windows\\Fonts\\StencilStd.otf',
#  'c:\\windows\\fonts\\trajanpro-bold.otf',
#  'c:\\windows\\fonts\\garait.ttf',
#  'C:\\Windows\\Fonts\\MyriadArabic-Regular.otf',
#  'C:\\Windows\\Fonts\\AurulentSans-Italic.otf',
#  'C:\\Windows\\Fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\andlso.ttf',
#  'C:\\Windows\\Fonts\\Hack-BoldItalic.ttf',
#  'c:\\windows\\fonts\\sanchezregular.otf',
#  'c:\\windows\\fonts\\palscri.ttf',
#  'C:\\Windows\\Fonts\\gautami.ttf',
#  'C:\\Windows\\Fonts\\OfficinaSansStd-Bold.otf',
#  'C:\\Windows\\Fonts\\Raleway-ExtraBold.ttf',
#  'c:\\windows\\fonts\\roboto-medium_0.ttf',
#  'C:\\Windows\\Fonts\\angsau.ttf',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'c:\\windows\\fonts\\browa.ttf',
#  'c:\\windows\\fonts\\notonaskharabic-regular.ttf',
#  'c:\\windows\\fonts\\rod.ttf',
#  'c:\\windows\\fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\LetterGothicStd-BoldSlanted.otf',
#  'c:\\windows\\fonts\\seguisym.ttf',
#  'C:\\Windows\\Fonts\\segoesc.ttf',
#  'C:\\Windows\\Fonts\\ROCKI.TTF',
#  'C:\\Windows\\Fonts\\VanillaDaisy-SS02.ttf',
#  'C:\\Windows\\Fonts\\raavi.ttf',
#  'c:\\windows\\fonts\\adobenaskh-medium.otf',
#  'C:\\Windows\\Fonts\\GOTHICBI.TTF',
#  'c:\\windows\\fonts\\georgiaz.ttf',
#  'c:\\windows\\fonts\\nirmala.ttf',
#  'c:\\windows\\fonts\\times.ttf',
#  'C:\\Windows\\Fonts\\NuevaStd-Italic.otf',
#  'C:\\Windows\\Fonts\\Vanib.ttf',
#  'c:\\windows\\fonts\\gillubcd.ttf',
#  'c:\\windows\\fonts\\refspcl.ttf',
#  'c:\\windows\\fonts\\verdanab.ttf',
#  'C:\\Windows\\Fonts\\mriamc.ttf',
#  'c:\\windows\\fonts\\shrutib.ttf',
#  'c:\\windows\\fonts\\erasdemi.ttf',
#  'c:\\windows\\fonts\\myriadhebrew-boldit.otf',
#  'C:\\Windows\\Fonts\\arial.ttf',
#  'c:\\windows\\fonts\\prestigeelitestd-bd.otf',
#  'C:\\Windows\\Fonts\\Roboto-LightItalic.ttf',
#  'c:\\windows\\fonts\\lettergothicstd-bold.otf',
#  'C:\\Windows\\Fonts\\upcfb.ttf',
#  'C:\\Windows\\Fonts\\MISTRAL.TTF',
#  'c:\\windows\\fonts\\roboto-light_0.ttf',
#  'C:\\Windows\\Fonts\\AdobeHebrew-Italic.otf',
#  'c:\\windows\\fonts\\adobefangsongstd-regular.otf',
#  'c:\\windows\\fonts\\colonna.ttf',
#  'c:\\windows\\fonts\\bell.ttf',
#  'c:\\windows\\fonts\\castelar.ttf',
#  'C:\\Windows\\Fonts\\RobotoCondensed-LightItalic.ttf',
#  'c:\\windows\\fonts\\lvnmbd.ttf',
#  'C:\\Windows\\Fonts\\DroidSerif-Bold.ttf',
#  'c:\\windows\\fonts\\simfang.ttf',
#  'c:\\windows\\fonts\\euphemia.ttf',
#  'C:\\Windows\\Fonts\\LTYPEB.TTF',
#  'C:\\Windows\\Fonts\\ELEPHNTI.TTF',
#  'c:\\windows\\fonts\\arial.ttf',
#  'c:\\windows\\fonts\\calibriz.ttf',
#  'C:\\Windows\\Fonts\\courbi.ttf',
#  'C:\\Windows\\Fonts\\MyriadPro-It.otf',
#  'c:\\windows\\fonts\\britanic.ttf',
#  'C:\\Windows\\Fonts\\TCM_____.TTF',
#  'C:\\Windows\\Fonts\\cordiaz.ttf',
#  'C:\\Windows\\Fonts\\georgiaz.ttf',
#  'c:\\windows\\fonts\\lfax.ttf',
#  'c:\\windows\\fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\VLADIMIR.TTF',
#  'c:\\windows\\fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\Windows\\Fonts\\angsab.ttf',
#  'C:\\Windows\\Fonts\\cordiai.ttf',
#  'c:\\windows\\fonts\\segoescb.ttf',
#  'c:\\windows\\fonts\\playbill.ttf',
#  'c:\\windows\\fonts\\majalla.ttf',
#  'C:\\Windows\\Fonts\\Shonarb.ttf',
#  'C:\\Windows\\Fonts\\OCRAStd.otf',
#  'C:\\Windows\\Fonts\\aparajb.ttf',
#  'c:\\windows\\fonts\\raleway-black.ttf',
#  'C:\\Windows\\Fonts\\REFSAN.TTF',
#  'C:\\Windows\\Fonts\\LithosPro-Regular.otf',
#  'c:\\windows\\fonts\\upckl.ttf',
#  'C:\\Windows\\Fonts\\Raleway-ExtraLight.ttf',
#  'c:\\windows\\fonts\\taileb.ttf',
#  'c:\\windows\\fonts\\angsaui.ttf',
#  'c:\\windows\\fonts\\kunstler.ttf',
#  'c:\\windows\\fonts\\lithospro-black.otf',
#  'c:\\windows\\fonts\\arialnb.ttf',
#  'c:\\windows\\fonts\\aurulentsans-regular.otf',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\AurulentSans-Regular.otf',
#  'C:\\Windows\\Fonts\\david.ttf',
#  'c:\\windows\\fonts\\latinwd.ttf',
#  'c:\\windows\\fonts\\vrinda.ttf',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'c:\\windows\\fonts\\lathab.ttf',
#  'c:\\windows\\fonts\\notosansmonocjktc-bold.otf',
#  'C:\\Windows\\Fonts\\FORTE.TTF',
#  'c:\\windows\\fonts\\georgiab.ttf',
#  'C:\\Windows\\Fonts\\FRADM.TTF',
#  'c:\\windows\\fonts\\tektonpro-bold.otf',
#  'c:\\windows\\fonts\\agaramondpro-regular.otf',
#  'c:\\windows\\fonts\\myriadarabic-bold.otf',
#  'c:\\windows\\fonts\\birchstd.otf',
#  'C:\\Windows\\Fonts\\BOD_PSTC.TTF',
#  'C:\\Windows\\Fonts\\SIMPLIFICA Typeface.ttf',
#  'c:\\windows\\fonts\\myriadpro-bold.otf',
#  'c:\\windows\\fonts\\censcbk.ttf',
#  'C:\\Windows\\Fonts\\Sauce Code Powerline Regular.otf',
#  'C:\\Windows\\Fonts\\segoeui.ttf',
#  'C:\\Windows\\Fonts\\times.ttf',
#  'C:\\Windows\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\cordia.ttf',
#  'C:\\Windows\\Fonts\\BELLI.TTF',
#  'c:\\windows\\fonts\\notoemoji-regular.ttf',
#  'c:\\windows\\fonts\\moolbor.ttf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'c:\\windows\\fonts\\myriadhebrew-it.otf',
#  'c:\\windows\\fonts\\ahronbd.ttf',
#  'C:\\Windows\\Fonts\\segoepr.ttf',
#  'c:\\windows\\fonts\\roboto-bold_0.ttf',
#  'C:\\Windows\\Fonts\\NotoSans-Bold.ttf',
#  'c:\\windows\\fonts\\califr.ttf',
#  'C:\\Windows\\Fonts\\ebrima.ttf',
#  'c:\\windows\\fonts\\calist.ttf',
#  'c:\\windows\\fonts\\browauz.ttf',
#  'C:\\Windows\\Fonts\\BOD_BLAR.TTF',
#  'C:\\Windows\\Fonts\\KozMinPr6N-Medium.otf',
#  'C:\\Windows\\Fonts\\COOPBL.TTF',
#  'c:\\windows\\fonts\\palai.ttf',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\trebucit.ttf',
#  'C:\\Windows\\Fonts\\NuevaStd-Bold.otf',
#  'C:\\Windows\\Fonts\\ITCEDSCR.TTF',
#  'C:\\Windows\\Fonts\\GOUDOSB.TTF',
#  'c:\\windows\\fonts\\phagspab.ttf',
#  'C:\\Windows\\Fonts\\arialbd.ttf',
#  'c:\\windows\\fonts\\bookosb.ttf',
#  'C:\\Windows\\Fonts\\tunga.ttf',
#  'C:\\Windows\\Fonts\\VanillaDaisy-SS06.ttf',
#  'c:\\windows\\fonts\\onyx.ttf',
#  'C:\\Windows\\Fonts\\gautamib.ttf',
#  'C:\\Windows\\Fonts\\upcebi.ttf',
#  'C:\\Windows\\Fonts\\ELEPHNT.TTF',
#  'C:\\Windows\\Fonts\\PERTIBD.TTF',
#  'c:\\windows\\fonts\\dejavusans-boldoblique.ttf',
#  'c:\\windows\\fonts\\frabkit.ttf',
#  'c:\\windows\\fonts\\itckrist.ttf',
#  'c:\\windows\\fonts\\arabtype.ttf',
#  'C:\\Windows\\Fonts\\trebucbi.ttf',
#  'C:\\Windows\\Fonts\\MinionPro-Regular.otf',
#  'C:\\Windows\\Fonts\\BRLNSDB.TTF',
#  'C:\\Windows\\Fonts\\RobotoCondensed-Italic.ttf',
#  'c:\\windows\\fonts\\mtcorsva.ttf',
#  'C:\\Windows\\Fonts\\upcfbi.ttf',
#  'C:\\Windows\\Fonts\\DejaVuSans-BoldOblique.ttf',
#  'C:\\Windows\\Fonts\\estre.ttf',
#  'C:\\Windows\\Fonts\\Brotherhood_Script.ttf',
#  'C:\\Windows\\Fonts\\VanillaDaisy-SS01.ttf',
#  'c:\\windows\\fonts\\showg.ttf',
#  'c:\\windows\\fonts\\tempsitc.ttf',
#  'c:\\windows\\fonts\\upcii.ttf',
#  'c:\\windows\\fonts\\kozminpr6n-bold.otf',
#  'c:\\windows\\fonts\\angsa.ttf',
#  'C:\\Windows\\Fonts\\AdobeGothicStd-Bold.otf',
#  'c:\\windows\\fonts\\taile.ttf',
#  'c:\\windows\\fonts\\rocki.ttf',
#  'c:\\windows\\fonts\\roboto-regular_0.ttf',
#  'C:\\Windows\\Fonts\\georgiai.ttf',
#  'c:\\windows\\fonts\\upcll.ttf',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\CURLZ___.TTF',
#  'C:\\Windows\\Fonts\\ACaslonPro-Regular.otf',
#  'c:\\windows\\fonts\\corbeli.ttf',
#  'c:\\windows\\fonts\\gabriola.ttf',
#  'c:\\windows\\fonts\\upcfb.ttf',
#  'C:\\Windows\\Fonts\\DejaVuSans-Oblique.ttf',
#  'C:\\Windows\\Fonts\\RobotoCondensed-Light_0.ttf',
#  'c:\\windows\\fonts\\lbritedi.ttf',
#  'C:\\Windows\\Fonts\\BOOKOS.TTF',
#  'c:\\program files (x86)\\adobe\\acrobat 2015\\resource\\font\\adobedevanagari-italic.otf',
#  'C:\\Windows\\Fonts\\VanillaDaisy-SS05.ttf',
#  'c:\\windows\\fonts\\raavi.ttf',
#  'C:\\Windows\\Fonts\\upcji.ttf',
#  'c:\\windows\\fonts\\myriadarabic-boldit.otf',
#  'C:\\Windows\\Fonts\\upclbi.ttf',
#  'C:\\Windows\\Fonts\\Raleway-Regular.ttf',
#  'c:\\windows\\fonts\\trajanpro-regular.otf',
#  'C:\\Windows\\Fonts\\KozGoPr6N-Light.otf',
#  'C:\\Windows\\Fonts\\sylfaen.ttf',
#  'c:\\windows\\fonts\\acaslonpro-bold.otf',
#  'C:\\Windows\\Fonts\\tahomabd.ttf',
#  'c:\\windows\\fonts\\lbrited.ttf',
#  'c:\\windows\\fonts\\upcfi.ttf',
#  'c:\\windows\\fonts\\brotherhood_script.ttf',
#  'C:\\Windows\\Fonts\\KozMinPr6N-Bold.otf',
#  'C:\\Windows\\Fonts\\GILSANUB.TTF',
#  'C:\\Windows\\Fonts\\AGENCYB.TTF',
#  'C:\\Windows\\Fonts\\FELIXTI.TTF',
#  'c:\\windows\\fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\KozGoPr6N-Medium.otf',
#  'C:\\Windows\\Fonts\\GILC____.TTF',
#  'c:\\windows\\fonts\\kozminpr6n-light.otf',
#  'c:\\windows\\fonts\\harlowsi.ttf',
#  'c:\\windows\\fonts\\tahoma.ttf',
#  'c:\\windows\\fonts\\upcli.ttf',
#  'c:\\windows\\fonts\\chaparralpro-boldit.otf',
#  'C:\\Windows\\Fonts\\cambriab.ttf',
#  'C:\\Windows\\Fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\upcii.ttf',
#  'c:\\windows\\fonts\\tungab.ttf',
#  'c:\\windows\\fonts\\adobeheitistd-regular.otf',
#  'c:\\windows\\fonts\\librebaskerville-regular.otf',
#  'C:\\Windows\\Fonts\\Hack-Italic.ttf',
#  'C:\\Windows\\Fonts\\Existence-UnicaseLight.otf',
#  'c:\\windows\\fonts\\dejavusanscondensed.ttf',
#  'C:\\Windows\\Fonts\\NotoEmoji-Regular.ttf',
#  'C:\\Windows\\Fonts\\upckbi.ttf',
#  'C:\\Windows\\Fonts\\ONYX.TTF',
#  'C:\\Windows\\Fonts\\browaui.ttf',
#  'C:\\Windows\\Fonts\\AGaramondPro-Italic.otf',
#  'C:\\Windows\\Fonts\\gishabd.ttf',
#  'c:\\windows\\fonts\\bellb.ttf',
#  'C:\\Windows\\Fonts\\ROCKEB.TTF',
#  'C:\\Windows\\Fonts\\TCCEB.TTF',
#  'c:\\windows\\fonts\\minionpro-regular.otf',
#  'c:\\windows\\fonts\\fradm.ttf',
#  'c:\\windows\\fonts\\browaub.ttf',
#  'c:\\windows\\fonts\\tccm____.ttf',
#  'C:\\Windows\\Fonts\\ERASDEMI.TTF',
#  'C:\\Windows\\Fonts\\WINGDNG2.TTF',
#  'C:\\Windows\\Fonts\\MSUIGHUB.TTF',
#  'c:\\windows\\fonts\\droidserif-italic.ttf',
#  'c:\\windows\\fonts\\lfaxi.ttf',
#  'c:\\windows\\fonts\\trebucbi.ttf',
#  'c:\\windows\\fonts\\goudos.ttf',
#  'c:\\windows\\fonts\\frank.ttf',
#  'c:\\windows\\fonts\\mentone-semibol.otf',
#  'C:\\Windows\\Fonts\\CALIFB.TTF',
#  'C:\\Windows\\Fonts\\MTCORSVA.TTF',
#  'C:\\Windows\\Fonts\\Roboto-Medium.ttf',
#  'C:\\Windows\\Fonts\\SNAP____.TTF',
#  'c:\\windows\\fonts\\lfaxdi.ttf',
#  'c:\\windows\\fonts\\belli.ttf',
#  'C:\\Windows\\Fonts\\upcdi.ttf',
#  'c:\\windows\\fonts\\robotocondensed-light_0.ttf',
#  'C:\\Windows\\Fonts\\AdobeFangsongStd-Regular.otf',
#  'C:\\Windows\\Fonts\\kartikab.ttf',
#  'C:\\Windows\\Fonts\\Roboto-Light_0.ttf',
#  'C:\\Windows\\Fonts\\ACaslonPro-Italic.otf',
#  'c:\\windows\\fonts\\bod_cbi.ttf',
#  'C:\\Windows\\Fonts\\GreatVibes-Regular.ttf',
#  'c:\\windows\\fonts\\vijayab.ttf',
#  'c:\\windows\\fonts\\ebrima.ttf',
#  'c:\\windows\\fonts\\philosopher-bolditalic.ttf',
#  'C:\\Windows\\Fonts\\latha.ttf',
#  'C:\\Windows\\Fonts\\SEGOEUISL.TTF',
#  'c:\\windows\\fonts\\bod_cr.ttf',
#  'c:\\windows\\fonts\\msuighur.ttf',
#  'C:\\Windows\\Fonts\\PRISTINA.TTF',
#  'C:\\Windows\\Fonts\\RobotoCondensed-Regular_0.ttf',
#  'c:\\windows\\fonts\\philosopher-italic.ttf',
#  'C:\\Windows\\Fonts\\MinionPro-Bold.otf',
#  'c:\\windows\\fonts\\browau.ttf',
#  'C:\\Windows\\Fonts\\LaoUIb.ttf',
#  'C:\\Windows\\Fonts\\FRAHV.TTF',
#  'c:\\windows\\fonts\\hgrsmp.ttf',
#  'c:\\windows\\fonts\\bernhc.ttf',
#  'C:\\Windows\\Fonts\\Raleway-LightItalic.ttf',
#  'C:\\Windows\\Fonts\\Sauce Code Powerline Light.otf',
#  'C:\\Windows\\Fonts\\Roboto-BlackItalic.ttf',
#  'c:\\windows\\fonts\\calistb.ttf',
#  'C:\\Windows\\Fonts\\ANTQUAB.TTF',
#  'c:\\windows\\fonts\\minionpro-bold.otf',
#  'c:\\windows\\fonts\\nuevastd-boldconditalic.otf',
#  'C:\\Windows\\Fonts\\Sauce Code Powerline Bold.otf',
#  'c:\\windows\\fonts\\raleway-regular.ttf',
#  'C:\\Windows\\Fonts\\KozGoPr6N-Regular.otf',
#  'C:\\Windows\\Fonts\\BrushScriptStd.otf',
#  'C:\\Windows\\Fonts\\PERI____.TTF',
#  'C:\\Windows\\Fonts\\Roboto-Italic_0.ttf',
#  'c:\\windows\\fonts\\aurulentsans-bolditalic.otf',
#  'C:\\Windows\\Fonts\\KozMinPro-Bold.otf',
#  'c:\\windows\\fonts\\timesi.ttf',
#  'c:\\windows\\fonts\\msyi.ttf',
#  'c:\\windows\\fonts\\adobegothicstd-bold.otf',
#  'c:\\windows\\fonts\\leelawad.ttf',
#  'c:\\windows\\fonts\\ltypeb.ttf',
#  'c:\\windows\\fonts\\kalingab.ttf',
#  'C:\\Windows\\Fonts\\CENSCBK.TTF',
#  'c:\\windows\\fonts\\upcdbi.ttf',
#  'c:\\windows\\fonts\\shruti.ttf',
#  'C:\\Windows\\Fonts\\MyriadPro-CondIt.otf',
#  'C:\\Windows\\Fonts\\ROCKB.TTF',
#  'C:\\Windows\\Fonts\\GOTHIC.TTF',
#  'C:\\Windows\\Fonts\\MinionPro-BoldIt.otf',
#  'C:\\Windows\\Fonts\\BOD_CR.TTF',
#  'C:\\Windows\\Fonts\\PoplarStd.otf',
#  'C:\\Windows\\Fonts\\comic.ttf',
#  'c:\\windows\\fonts\\agaramondpro-italic.otf',
#  'C:\\Windows\\Fonts\\VanillaDaisy-SS03.ttf',
#  'c:\\windows\\fonts\\lettergothicstd-slanted.otf',
#  'C:\\Windows\\Fonts\\RobotoCondensed-Light.ttf',
#  'c:\\windows\\fonts\\cambriab.ttf',
#  'c:\\windows\\fonts\\refsan.ttf',
#  'C:\\Windows\\Fonts\\TCBI____.TTF',
#  'c:\\windows\\fonts\\charlemagnestd-bold.otf',
#  'c:\\windows\\fonts\\sourcecodepro-semibold.ttf',
#  'C:\\Windows\\Fonts\\upcjl.ttf',
#  'c:\\program files (x86)\\common files\\microsoft shared\\equation\\mtextra.ttf',
#  'c:\\windows\\fonts\\notoserif-italic.ttf',
#  'c:\\windows\\fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\ARIALUNI.TTF',
#  'C:\\Windows\\Fonts\\shrutib.ttf',
#  'c:\\windows\\fonts\\calisti.ttf',
#  'c:\\windows\\fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\NotoSansCJKtc-Regular.otf',
#  'c:\\windows\\fonts\\angsab.ttf',
#  'C:\\Windows\\Fonts\\GILB____.TTF',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'c:\\windows\\fonts\\lvnm.ttf',
#  'c:\\windows\\fonts\\lcallig.ttf',
#  'C:\\Windows\\Fonts\\ebrimabd.ttf',
#  'c:\\windows\\fonts\\segoeuii.ttf',
#  'c:\\windows\\fonts\\adobedevanagari-bolditalic.otf',
#  'C:\\Windows\\Fonts\\upckb.ttf',
#  'C:\\Windows\\Fonts\\BSSYM7.TTF',
#  'c:\\windows\\fonts\\nuevastd-boldcond.otf',
#  'c:\\windows\\fonts\\fradmit.ttf',
#  'c:\\windows\\fonts\\notonaskharabic-bold.ttf',
#  'c:\\windows\\fonts\\zwadobef.ttf',
#  'c:\\windows\\fonts\\kaiu.ttf',
#  'C:\\Windows\\Fonts\\Blacksword.otf',
#  'c:\\windows\\fonts\\droidserif-regular.ttf',
#  'C:\\Windows\\Fonts\\LBRITED.TTF',
#  'C:\\Windows\\Fonts\\BOOKOSB.TTF',
#  'C:\\Windows\\Fonts\\AdobeDevanagari-Bold.otf',
#  'C:\\Windows\\Fonts\\FRAHVIT.TTF',
#  'c:\\windows\\fonts\\dokchamp.ttf',
#  'c:\\windows\\fonts\\tccb____.ttf',
#  'c:\\windows\\fonts\\raleway-bold.ttf',
#  'c:\\windows\\fonts\\bod_cb.ttf',
#  'C:\\Windows\\Fonts\\SourceCodePro-ExtraLight.ttf',
#  'C:\\Windows\\Fonts\\Roboto-Light.ttf',
#  'C:\\Windows\\Fonts\\CASTELAR.TTF',
#  'c:\\windows\\fonts\\nuevastd-italic.otf',
#  'C:\\Windows\\Fonts\\RobotoCondensed-Regular.ttf',
#  'c:\\windows\\fonts\\tcbi____.ttf',
#  'C:\\Windows\\Fonts\\KozGoPro-Bold.otf',
#  'c:\\windows\\fonts\\tektonpro-boldobl.otf',
#  'C:\\Windows\\Fonts\\upcll.ttf',
#  'C:\\Windows\\Fonts\\Raleway-Bold.ttf',
#  'c:\\windows\\fonts\\frahvit.ttf',
#  'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\NotoSerif-Regular.ttf',
#  'c:\\windows\\fonts\\upcfbi.ttf',
#  'c:\\windows\\fonts\\shonar.ttf',
#  'c:\\windows\\fonts\\roboto-bolditalic_0.ttf',
#  'c:\\windows\\fonts\\raleway-mediumitalic.ttf',
#  'C:\\Windows\\Fonts\\CALISTB.TTF',
#  'c:\\windows\\fonts\\ariblk.ttf',
#  'c:\\windows\\fonts\\adobehebrew-regular.otf',
#  'c:\\windows\\fonts\\adobedevanagari-regular.otf',
#  'c:\\windows\\fonts\\l_10646.ttf',
#  'c:\\windows\\fonts\\bookosbi.ttf',
#  'c:\\windows\\fonts\\bssym7.ttf',
#  'C:\\Windows\\Fonts\\GILI____.TTF',
#  'c:\\windows\\fonts\\bookos.ttf',
#  'c:\\windows\\fonts\\myriadpro-semiboldit.otf',
#  'c:\\windows\\fonts\\gilb____.ttf',
#  'c:\\windows\\fonts\\officinasansstd-bold.otf',
#  'C:\\Windows\\Fonts\\ERASBD.TTF',
#  'C:\\Windows\\Fonts\\KozMinPr6N-Regular.otf',
#  'c:\\windows\\fonts\\lettergothicstd-boldslanted.otf',
#  'C:\\Windows\\Fonts\\tungab.ttf',
#  'C:\\Windows\\Fonts\\ROCKBI.TTF',
#  'c:\\windows\\fonts\\ebrimabd.ttf',
#  'c:\\windows\\fonts\\intriquescript_personaluse.ttf',
#  'c:\\windows\\fonts\\nirmalab.ttf',
#  'c:\\windows\\fonts\\felixti.ttf',
#  'c:\\windows\\fonts\\segoeprb.ttf',
#  'c:\\windows\\fonts\\tcmi____.ttf',
#  'C:\\Windows\\Fonts\\MinionPro-MediumIt.otf',
#  'C:\\Windows\\Fonts\\NotoNaskhArabic-Bold.ttf',
#  'c:\\windows\\fonts\\seguisb.ttf',
#  'c:\\windows\\fonts\\symbol.ttf',
#  'C:\\Windows\\Fonts\\SourceCodePro-Light.ttf',
#  'C:\\Windows\\Fonts\\BELLB.TTF',
#  'C:\\Windows\\Fonts\\BOD_BLAI.TTF',
#  'c:\\windows\\fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\upcib.ttf',
#  'C:\\Windows\\Fonts\\Raleway-ExtraBoldItalic.ttf',
#  'C:\\Windows\\Fonts\\KozMinPr6N-ExtraLight.otf',
#  'c:\\windows\\fonts\\chiller.ttf',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'c:\\windows\\fonts\\mistral.ttf',
#  'C:\\Windows\\Fonts\\BKANT.TTF',
#  'C:\\Windows\\Fonts\\ACaslonPro-SemiboldItalic.otf',
#  'c:\\windows\\fonts\\adobearabic-bolditalic.otf',
#  'c:\\windows\\fonts\\dense-regular.otf',
#  'c:\\windows\\fonts\\notoserif-bold.ttf',
#  'C:\\Windows\\Fonts\\msyh.ttf',
#  'C:\\Windows\\Fonts\\BRITANIC.TTF',
#  'c:\\windows\\fonts\\kozminpro-regular.otf',
#  'C:\\Windows\\Fonts\\CENTAUR.TTF',
#  'C:\\Windows\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\upcil.ttf',
#  'C:\\Windows\\Fonts\\KozMinPr6N-Heavy.otf',
#  'c:\\windows\\fonts\\brushscriptstd.otf',
#  'C:\\Windows\\Fonts\\Philosopher-BoldItalic.ttf',
#  'C:\\Windows\\Fonts\\NuevaStd-BoldCond.otf',
#  'C:\\Windows\\Fonts\\MyriadHebrew-Regular.otf',
#  'C:\\Windows\\Fonts\\RosewoodStd-Regular.otf',
#  'C:\\Windows\\Fonts\\BROADW.TTF',
#  'c:\\windows\\fonts\\arialnbi.ttf',
#  'C:\\Windows\\Fonts\\DroidSerif-BoldItalic.ttf',
#  'c:\\windows\\fonts\\notosansmonocjktc-regular.otf',
#  'C:\\Windows\\Fonts\\ACaslonPro-Bold.otf',
#  'C:\\Windows\\Fonts\\IntriqueScript_PersonalUse.ttf',
#  'C:\\Windows\\Fonts\\OCRB.TTF',
#  'C:\\Windows\\Fonts\\LEELAWDB.TTF',
#  'C:\\Windows\\Fonts\\LSANS.TTF',
#  'c:\\windows\\fonts\\gilc____.ttf',
#  'C:\\Windows\\Fonts\\Raleway-Black.ttf',
#  'C:\\Windows\\Fonts\\Raleway-SemiBoldItalic.ttf',
#  'C:\\Windows\\Fonts\\CharlemagneStd-Bold.otf',
#  'c:\\windows\\fonts\\notosanscjktc-medium.otf',
#  'c:\\windows\\fonts\\corbelz.ttf',
#  'c:\\windows\\fonts\\gishabd.ttf',
#  'c:\\windows\\fonts\\vanilladaisy-ss01.ttf',
#  'C:\\Windows\\Fonts\\Roboto-Regular_0.ttf',
#  'C:\\Windows\\Fonts\\ACaslonPro-BoldItalic.otf',
#  'c:\\windows\\fonts\\arvo-italic.ttf',
#  'C:\\Windows\\Fonts\\AdobeArabic-Bold.otf',
#  'C:\\Windows\\Fonts\\ANTQUABI.TTF',
#  'c:\\windows\\fonts\\droidserif-bold.ttf',
#  'c:\\windows\\fonts\\david.ttf',
#  'c:\\windows\\fonts\\hack-regular.ttf',
#  'C:\\Windows\\Fonts\\ChaparralPro-BoldIt.otf',
#  'C:\\Windows\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\ARLRDBD.TTF',
#  'C:\\Windows\\Fonts\\Hack-Bold.ttf',
#  'C:\\Windows\\Fonts\\SCRIPTBL.TTF',
#  'c:\\windows\\fonts\\kozminpro-light.otf',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\LetterGothicStd-Bold.otf',
#  'c:\\windows\\fonts\\lbritei.ttf',
#  'c:\\windows\\fonts\\raleway-extralight.ttf',
#  'c:\\windows\\fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\JOKERMAN.TTF',
#  'c:\\windows\\fonts\\agaramondpro-bold.otf',
#  'c:\\windows\\fonts\\schlbkbi.ttf',
#  'C:\\Windows\\Fonts\\AdobeKaitiStd-Regular.otf',
#  'c:\\windows\\fonts\\constanz.ttf',
#  'c:\\windows\\fonts\\simsunb.ttf',
#  'c:\\windows\\fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\FREESCPT.TTF',
#  'C:\\Windows\\Fonts\\LibreBaskerville-Bold.otf',
#  'C:\\Windows\\Fonts\\SourceCodePro-Black.ttf',
#  'C:\\Windows\\Fonts\\LEELAWAD.TTF',
#  'C:\\Windows\\Fonts\\TCCB____.TTF',
#  'c:\\windows\\fonts\\angsau.ttf',
#  'c:\\windows\\fonts\\vanilladaisy-ss03.ttf',
#  'C:\\Windows\\Fonts\\AGaramondPro-Regular.otf',
#  'C:\\Windows\\Fonts\\timesbi.ttf',
#  'c:\\windows\\fonts\\andlso.ttf',
#  'c:\\windows\\fonts\\raleway-extrabold.ttf',
#  'C:\\Windows\\Fonts\\LBRITE.TTF',
#  'c:\\windows\\fonts\\khmerui.ttf',
#  'C:\\Windows\\Fonts\\NIAGSOL.TTF',
#  'c:\\windows\\fonts\\kokila.ttf',
#  'c:\\windows\\fonts\\upcdb.ttf',
#  'C:\\Windows\\Fonts\\LTYPE.TTF',
#  'c:\\windows\\fonts\\eraslght.ttf',
#  'C:\\Windows\\Fonts\\MyriadPro-BoldIt.otf',
#  'c:\\windows\\fonts\\greatvibes-regular.ttf',
#  'C:\\Windows\\Fonts\\NotoSansCJKtc-Medium.otf',
#  'c:\\windows\\fonts\\rockbi.ttf',
#  'c:\\windows\\fonts\\adobehebrew-bolditalic.otf',
#  'C:\\Windows\\Fonts\\calibri.ttf',
#  'c:\\windows\\fonts\\upckb.ttf',
#  'c:\\windows\\fonts\\bod_b.ttf',
#  'C:\\Windows\\Fonts\\upcdl.ttf',
#  'C:\\Windows\\Fonts\\TCB_____.TTF',
#  'C:\\Windows\\Fonts\\cordiab.ttf',
#  'c:\\windows\\fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\arialbi.ttf',
#  'C:\\Windows\\Fonts\\MesquiteStd.otf',
#  'C:\\Windows\\Fonts\\Dancing Script.ttf',
#  'C:\\Windows\\Fonts\\MyriadPro-BoldCondIt.otf',
#  'C:\\Windows\\Fonts\\ChaparralPro-Regular.otf',
#  'c:\\windows\\fonts\\robotocondensed-bold_0.ttf',
#  'c:\\windows\\fonts\\utsaahi.ttf',
#  'C:\\Windows\\Fonts\\AurulentSans-BoldItalic.otf',
#  'c:\\windows\\fonts\\hobostd.otf',
#  'C:\\Windows\\Fonts\\ROCC____.TTF',
#  'c:\\windows\\fonts\\cordia.ttf',
#  'C:\\Windows\\Fonts\\trebuc.ttf',
#  'c:\\windows\\fonts\\upcil.ttf',
#  'c:\\windows\\fonts\\himalaya.ttf',
#  'c:\\windows\\fonts\\lsansdi.ttf',
#  'C:\\Windows\\Fonts\\trado.ttf',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\simfang.ttf',
#  'c:\\windows\\fonts\\ariali.ttf',
#  'c:\\windows\\fonts\\aparaji.ttf',
#  'c:\\windows\\fonts\\sylfaen.ttf',
#  'c:\\windows\\fonts\\coprgtl.ttf',
#  'c:\\windows\\fonts\\cambriai.ttf',
#  'C:\\Windows\\Fonts\\AurulentSans-Bold.otf',
#  'c:\\windows\\fonts\\century.ttf',
#  'c:\\windows\\fonts\\brlnsb.ttf',
#  'c:\\windows\\fonts\\antquabi.ttf',
#  'c:\\windows\\fonts\\aurulentsans-bold.otf',
#  'c:\\windows\\fonts\\kozgopro-heavy.otf',
#  'c:\\windows\\fonts\\adobemingstd-light.otf',
#  'c:\\windows\\fonts\\gautami.ttf',
#  'C:\\Windows\\Fonts\\HYvgU2fE2nRJvZ5JFAumwZS3E-kSBmtLoNJPDtbj2Pk.ttf',
#  'C:\\Windows\\Fonts\\AdobeArabic-Regular.otf',
#  'c:\\windows\\fonts\\simpbdo.ttf',
#  'c:\\windows\\fonts\\antquai.ttf',
#  'c:\\windows\\fonts\\nuevastd-conditalic.otf',
#  'c:\\windows\\fonts\\parchm.ttf',
#  'C:\\Windows\\Fonts\\BASKVILL.TTF',
#  'C:\\Windows\\Fonts\\NotoSansCJKtc-DemiLight.otf',
#  'c:\\windows\\fonts\\vivaldii.ttf',
#  'c:\\windows\\fonts\\sourcecodepro-black.ttf',
#  'C:\\Windows\\Fonts\\ipag.ttf',
#  'C:\\Windows\\Fonts\\SCHLBKB.TTF',
#  'c:\\windows\\fonts\\arialbd.ttf',
#  'c:\\windows\\fonts\\notoserif-bolditalic.ttf',
#  'C:\\Windows\\Fonts\\VanillaDaisy-SS00.ttf',
#  'c:\\windows\\fonts\\arvo-bold.ttf',
#  'C:\\Windows\\Fonts\\MyriadPro-Bold.otf',
#  'c:\\windows\\fonts\\dejavusanscondensed-oblique.ttf',
#  'c:\\windows\\fonts\\kozminpr6n-extralight.otf',
#  'C:\\Windows\\Fonts\\RobotoCondensed-Bold_0.ttf',
#  'c:\\windows\\fonts\\sanchezregular-ita.otf',
#  'C:\\Windows\\Fonts\\GOUDYSTO.TTF',
#  'C:\\Windows\\Fonts\\NotoSerif-Bold.ttf',
#  'C:\\Windows\\Fonts\\utsaahbi.ttf',
#  'C:\\Windows\\Fonts\\upcel.ttf',
#  'c:\\windows\\fonts\\simkai.ttf',
#  'c:\\windows\\fonts\\philosopher-regular.ttf',
#  'C:\\Windows\\Fonts\\KozGoPro-Light.otf',
#  'c:\\windows\\fonts\\lucon.ttf',
#  'c:\\windows\\fonts\\minionpro-semiboldit.otf',
#  'C:\\Windows\\Fonts\\LSANSDI.TTF',
#  'c:\\windows\\fonts\\acaslonpro-italic.otf',
#  'C:\\Windows\\Fonts\\MyriadPro-Semibold.otf',
#  'C:\\Windows\\Fonts\\DejaVuSansCondensed.ttf',
#  'c:\\windows\\fonts\\peri____.ttf',
#  'C:\\Windows\\Fonts\\LBRITEDI.TTF',
#  'C:\\Windows\\Fonts\\MyriadArabic-It.otf',
#  'c:\\windows\\fonts\\aurulentsans-italic.otf',
#  'c:\\windows\\fonts\\oratorstd.otf',
#  'C:\\Windows\\Fonts\\marlett.ttf',
#  'C:\\Windows\\Fonts\\upcdbi.ttf',
#  'C:\\Windows\\Fonts\\PERB____.TTF',
#  'c:\\windows\\fonts\\upcfl.ttf',
#  'C:\\Windows\\Fonts\\Sanchezregular.otf',
#  'c:\\windows\\fonts\\upclbi.ttf',
#  'c:\\windows\\fonts\\kozgopr6n-light.otf',
#  'c:\\windows\\fonts\\cordiab.ttf',
#  'C:\\Windows\\Fonts\\corbel.ttf',
#  'c:\\windows\\fonts\\myriadpro-boldcondit.otf',
#  'c:\\windows\\fonts\\minionpro-boldcn.otf',
#  'c:\\windows\\fonts\\comfortaa_thin.ttf',
#  'C:\\Windows\\Fonts\\AdobeHebrew-Regular.otf',
#  'c:\\windows\\fonts\\vladimir.ttf',
#  'C:\\Windows\\Fonts\\corbelb.ttf',
#  'C:\\Windows\\Fonts\\euphemia.ttf',
#  'C:\\Windows\\Fonts\\cordiau.ttf',
#  'C:\\Windows\\Fonts\\Roboto-Thin.ttf',
#  'c:\\windows\\fonts\\upcdi.ttf',
#  'C:\\Windows\\Fonts\\Roboto-BoldItalic.ttf',
#  'C:\\Windows\\Fonts\\upceb.ttf',
#  'c:\\windows\\fonts\\cordiauz.ttf',
#  'C:\\Windows\\Fonts\\TEMPSITC.TTF',
#  'C:\\Windows\\Fonts\\MinionPro-BoldCn.otf',
#  'C:\\Windows\\Fonts\\utsaah.ttf',
#  'c:\\windows\\fonts\\comfortaa_regular.ttf',
#  'c:\\windows\\fonts\\segoeuiz.ttf',
#  'c:\\windows\\fonts\\notosanscjktc-regular.otf',
#  'c:\\windows\\fonts\\timesbi.ttf',
#  'C:\\Windows\\Fonts\\MyriadPro-SemiboldIt.otf',
#  'c:\\windows\\fonts\\upcei.ttf',
#  'c:\\windows\\fonts\\dejavusans-extralight.ttf',
#  'C:\\Windows\\Fonts\\BonvenoCF-Light.otf',
#  'C:\\Windows\\Fonts\\tradbdo.ttf',
#  'c:\\windows\\fonts\\bkant.ttf',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'c:\\windows\\fonts\\mangalb.ttf',
#  'c:\\windows\\fonts\\kozgopr6n-medium.otf',
#  'C:\\Windows\\Fonts\\PAPYRUS.TTF',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'c:\\windows\\fonts\\bradhitc.ttf',
#  'c:\\windows\\fonts\\raleway-thin.ttf',
#  'C:\\Windows\\Fonts\\LBRITEI.TTF',
#  'C:\\Windows\\Fonts\\Candara.ttf',
#  'c:\\windows\\fonts\\ocraext.ttf',
#  'c:\\windows\\fonts\\existence-stencillight.otf',
#  'c:\\windows\\fonts\\calibrib.ttf',
#  'C:\\Windows\\Fonts\\POORICH.TTF',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'c:\\windows\\fonts\\upcibi.ttf',
#  'C:\\Windows\\Fonts\\AdobeHebrew-Bold.otf',
#  'c:\\windows\\fonts\\minionpro-boldcnit.otf',
#  'C:\\Windows\\Fonts\\BOD_BI.TTF',
#  'C:\\Windows\\Fonts\\SourceCodePro-Regular.ttf',
#  'c:\\windows\\fonts\\upckbi.ttf',
#  'C:\\Windows\\Fonts\\DejaVuSansCondensed-BoldOblique.ttf',
#  'C:\\Windows\\Fonts\\Roboto-Regular.ttf',
#  'C:\\Windows\\Fonts\\NIRMALAB.TTF',
#  'c:\\windows\\fonts\\ltypebo.ttf',
#  'c:\\windows\\fonts\\arvo-regular.ttf',
#  'C:\\Windows\\Fonts\\GILLUBCD.TTF',
#  'C:\\Windows\\Fonts\\nyala.ttf',
#  'C:\\Windows\\Fonts\\BOD_CI.TTF',
#  'C:\\Windows\\Fonts\\BELL.TTF',
#  'c:\\windows\\fonts\\cambriaz.ttf',
#  'C:\\Windows\\Fonts\\LibreBaskerville-Italic.otf',
#  'c:\\windows\\fonts\\kartika.ttf',
#  'c:\\windows\\fonts\\simpo.ttf',
#  'c:\\windows\\fonts\\consolai.ttf',
#  'C:\\Windows\\Fonts\\INFROMAN.TTF',
#  'C:\\Windows\\Fonts\\couri.ttf',
#  'C:\\Windows\\Fonts\\TCMI____.TTF',
#  'C:\\Windows\\Fonts\\Arvo-Italic.ttf',
#  'c:\\windows\\fonts\\kozminpr6n-medium.otf',
#  'C:\\Windows\\Fonts\\KozGoPro-ExtraLight.otf',
#  'C:\\Windows\\Fonts\\webdings.ttf',
#  'c:\\windows\\fonts\\candaraz.ttf',
#  'c:\\windows\\fonts\\raleway-medium.ttf',
#  'C:\\Windows\\Fonts\\AdobeDevanagari-BoldItalic.otf',
#  'C:\\Windows\\Fonts\\Vani.ttf',
#  'c:\\windows\\fonts\\htowerti.ttf',
#  'c:\\windows\\fonts\\robotocondensed-regular_0.ttf',
#  'C:\\Windows\\Fonts\\NotoNaskhArabic-Regular.ttf',
#  'c:\\windows\\fonts\\utsaah.ttf',
#  'c:\\windows\\fonts\\imprisha.ttf',
#  'C:\\Windows\\Fonts\\SHOWG.TTF',
#  'C:\\Windows\\Fonts\\NuevaStd-CondItalic.otf',
#  'C:\\Windows\\Fonts\\PLAYBILL.TTF',
#  'c:\\windows\\fonts\\notosanscjktc-bold.otf',
#  'c:\\windows\\fonts\\notosans-bolditalic.ttf',
#  'C:\\Windows\\Fonts\\MyriadHebrew-It.otf',
#  'c:\\windows\\fonts\\cooperblackstd-italic.otf',
#  'c:\\windows\\fonts\\lithospro-regular.otf',
#  'C:\\Windows\\Fonts\\RobotoCondensed-Italic_0.ttf',
#  'c:\\windows\\fonts\\trebucit.ttf',
#  'C:\\Windows\\Fonts\\KozGoPro-Medium.otf',
#  'c:\\windows\\fonts\\hgrskp.ttf',
#  'C:\\Windows\\Fonts\\Arvo-BoldItalic.ttf',
#  'C:\\Windows\\Fonts\\upcei.ttf',
#  'c:\\windows\\fonts\\framdcn.ttf',
#  'C:\\Windows\\Fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\CooperBlackStd.otf',
#  'c:\\windows\\fonts\\segoepr.ttf',
#  'c:\\windows\\fonts\\maturasc.ttf',
#  'C:\\Windows\\Fonts\\OratorStd.otf',
#  'c:\\windows\\fonts\\estre.ttf',
#  'c:\\windows\\fonts\\segoeuib.ttf',
#  'C:\\Windows\\Fonts\\KozMinPr6N-Light.otf',
#  'C:\\Windows\\Fonts\\ROCCB___.TTF',
#  'c:\\windows\\fonts\\sauce code powerline regular.otf',
#  'c:\\windows\\fonts\\mriam.ttf',
#  'C:\\Windows\\Fonts\\KozGoPro-Regular.otf',
#  'C:\\Windows\\Fonts\\LFAXDI.TTF',
#  'c:\\windows\\fonts\\roboto-italic_0.ttf',
#  'c:\\windows\\fonts\\gautamib.ttf',
#  'C:\\Windows\\Fonts\\GARAIT.TTF',
#  'c:\\windows\\fonts\\minionpro-medium.otf',
#  'C:\\Windows\\Fonts\\constanz.ttf',
#  'c:\\windows\\fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\CALIFI.TTF',
#  'C:\\Windows\\Fonts\\TrajanPro-Regular.otf',
#  'c:\\windows\\fonts\\lsans.ttf',
#  'c:\\windows\\fonts\\angsauz.ttf',
#  'c:\\program files (x86)\\adobe\\acrobat 2015\\resource\\font\\adobedevanagari-bolditalic.otf',
#  'c:\\windows\\fonts\\scriptbl.ttf',
#  'c:\\windows\\fonts\\roboto-thinitalic_0.ttf',
#  'c:\\windows\\fonts\\alger.ttf',
#  'C:\\Windows\\Fonts\\HoboStd.otf',
#  'C:\\Windows\\Fonts\\iskpotab.ttf',
#  'c:\\windows\\fonts\\blackoakstd.otf',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\Philosopher-Bold.ttf',
#  'C:\\Windows\\Fonts\\mentone-semibol.otf',
#  'C:\\Windows\\Fonts\\MinionPro-BoldCnIt.otf',
#  'c:\\windows\\fonts\\glecb.ttf',
#  'C:\\Windows\\Fonts\\COPRGTB.TTF',
#  'C:\\Windows\\Fonts\\CALISTI.TTF',
#  'c:\\windows\\fonts\\candara.ttf',
#  'c:\\windows\\fonts\\trado.ttf',
#  'c:\\windows\\fonts\\nyala.ttf',
#  'c:\\windows\\fonts\\wingdng3.ttf',
#  'c:\\windows\\fonts\\simpfxo.ttf',
#  'C:\\Windows\\Fonts\\AdobeArabic-Italic.otf',
#  'C:\\Windows\\Fonts\\kokilab.ttf',
#  'c:\\windows\\fonts\\malgun.ttf',
#  'c:\\windows\\fonts\\garabd.ttf',
#  'C:\\Windows\\Fonts\\simpo.ttf',
#  'C:\\Windows\\Fonts\\LTYPEBO.TTF',
#  'c:\\windows\\fonts\\schlbkb.ttf',
#  'c:\\windows\\fonts\\chaparralpro-lightit.otf',
#  'C:\\Windows\\Fonts\\HTOWERTI.TTF',
#  'C:\\Windows\\Fonts\\browaz.ttf',
#  'c:\\windows\\fonts\\ntailub.ttf',
#  'C:\\Windows\\Fonts\\Raleway-ExtraLightItalic.ttf',
#  'c:\\windows\\fonts\\adobehebrew-italic.otf',
#  'c:\\windows\\fonts\\myriadpro-regular.otf',
#  'c:\\windows\\fonts\\roboto-thin_0.ttf',
#  'C:\\Windows\\Fonts\\GADUGIB.TTF',
#  'C:\\Windows\\Fonts\\NotoSansMonoCJKtc-Bold.otf',
#  'C:\\Windows\\Fonts\\Roboto-LightItalic_0.ttf',
#  'c:\\windows\\fonts\\agaramondpro-bolditalic.otf',
#  'c:\\windows\\fonts\\oldengl.ttf',
#  'C:\\Windows\\Fonts\\OCRAEXT.TTF',
#  'c:\\windows\\fonts\\myriadarabic-regular.otf',
#  'C:\\Windows\\Fonts\\BOD_CB.TTF',
#  'c:\\windows\\fonts\\vanib.ttf',
#  'C:\\Windows\\Fonts\\frank.ttf',
#  'c:\\windows\\fonts\\gil_____.ttf',
#  'c:\\windows\\fonts\\freescpt.ttf',
#  'C:\\Windows\\Fonts\\HigashiOme-Gothic-1.3i_0.ttf',
#  'C:\\Windows\\Fonts\\Roboto-BoldItalic_0.ttf',
#  'c:\\windows\\fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\RobotoCondensed-BoldItalic.ttf',
#  'c:\\windows\\fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\BOD_B.TTF',
#  'C:\\Windows\\Fonts\\consolai.ttf',
#  'c:\\windows\\fonts\\tradbdo.ttf',
#  'C:\\Windows\\Fonts\\ANTQUAI.TTF',
#  'c:\\windows\\fonts\\hack-bolditalic.ttf',
#  'C:\\Windows\\Fonts\\Roboto-Thin_0.ttf',
#  'c:\\windows\\fonts\\gilbi___.ttf',
#  'c:\\windows\\fonts\\vanilladaisy-ss00.ttf',
#  'C:\\Windows\\Fonts\\ARIALNB.TTF',
#  'C:\\Windows\\Fonts\\symbol.ttf',
#  'c:\\windows\\fonts\\kozgopro-light.otf',
#  'c:\\windows\\fonts\\gadugi.ttf',
#  'C:\\Windows\\Fonts\\Comfortaa_Regular.ttf',
#  'c:\\windows\\fonts\\stencilstd.otf',
#  'c:\\windows\\fonts\\adobefanheitistd-bold.otf',
#  'C:\\Windows\\Fonts\\BRUSHSCI.TTF',
#  'C:\\Windows\\Fonts\\verdanai.ttf',
#  'c:\\windows\\fonts\\stencil.ttf',
#  'C:\\Windows\\Fonts\\DejaVuSans.ttf',
#  'C:\\Windows\\Fonts\\majalla.ttf',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\MyriadPro-Cond.otf',
#  'c:\\windows\\fonts\\pertili.ttf',
#  'c:\\windows\\fonts\\kozminpro-heavy.otf',
#  'c:\\windows\\fonts\\calibri.ttf',
#  'c:\\windows\\fonts\\raleway-italic.ttf',
#  'c:\\windows\\fonts\\hagin_caps_medium.otf',
#  'c:\\windows\\fonts\\constani.ttf',
#  'c:\\windows\\fonts\\nuevastd-cond.otf',
#  'C:\\Windows\\Fonts\\gisha.ttf',
#  'c:\\windows\\fonts\\jokerman.ttf',
#  'c:\\windows\\fonts\\angsaub.ttf',
#  'C:\\Windows\\Fonts\\AGENCYR.TTF',
#  'C:\\Windows\\Fonts\\CALIFR.TTF',
#  'C:\\Windows\\Fonts\\AdobeSongStd-Light.otf',
#  'C:\\Windows\\Fonts\\verdanab.ttf',
#  'C:\\Windows\\Fonts\\FRADMIT.TTF',
#  'c:\\windows\\fonts\\coprgtb.ttf',
#  'C:\\Windows\\Fonts\\MinionPro-Semibold.otf',
#  'C:\\Windows\\Fonts\\HARNGTON.TTF',
#  'C:\\Windows\\Fonts\\LSANSD.TTF',
#  'c:\\windows\\fonts\\arialni.ttf',
#  'C:\\Windows\\Fonts\\LFAX.TTF',
#  'c:\\windows\\fonts\\ltypeo.ttf',
#  'c:\\windows\\fonts\\bauhs93.ttf',
#  'C:\\Windows\\Fonts\\DroidSerif-Italic.ttf',
#  'C:\\Windows\\Fonts\\Hagin Caps Thin.otf',
#  'c:\\windows\\fonts\\notosanscjktc-light.otf',
#  'C:\\Windows\\Fonts\\KozGoPr6N-Heavy.otf',
#  'c:\\windows\\fonts\\baskvill.ttf',
#  'c:\\windows\\fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\ZWAdobeF.TTF',
#  'c:\\windows\\fonts\\bod_ci.ttf',
#  'C:\\Windows\\Fonts\\ChaparralPro-LightIt.otf',
#  'c:\\windows\\fonts\\tcceb.ttf',
#  'C:\\Windows\\Fonts\\HTOWERT.TTF',
#  'C:\\Windows\\Fonts\\Alcubierre.otf',
#  'C:\\Windows\\Fonts\\Roboto-MediumItalic_0.ttf',
#  'c:\\windows\\fonts\\dejavusans-oblique.ttf',
#  'C:\\Windows\\Fonts\\NotoSansCJKtc-Light.otf',
#  'c:\\windows\\fonts\\elephnti.ttf',
#  'C:\\Windows\\Fonts\\georgiab.ttf',
#  'c:\\windows\\fonts\\kozgopro-regular.otf',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'c:\\windows\\fonts\\georgiai.ttf',
#  'C:\\Windows\\Fonts\\mangalb.ttf',
#  'C:\\Windows\\Fonts\\Roboto-Italic.ttf',
#  'C:\\Windows\\Fonts\\BOD_I.TTF',
#  'C:\\Windows\\Fonts\\AdobeNaskh-Medium.otf',
#  'C:\\Windows\\Fonts\\TektonPro-BoldObl.otf',
#  'C:\\Windows\\Fonts\\GLSNECB.TTF',
#  'c:\\windows\\fonts\\pala.ttf',
#  'C:\\Windows\\Fonts\\KozMinPro-ExtraLight.otf',
#  'C:\\Windows\\Fonts\\majallab.ttf',
#  'c:\\windows\\fonts\\pertibd.ttf',
#  'C:\\Windows\\Fonts\\Raleway-SemiBold_0.ttf',
#  'C:\\Windows\\Fonts\\NotoSansMonoCJKtc-Regular.otf',
#  'c:\\windows\\fonts\\browab.ttf',
#  'C:\\Windows\\Fonts\\lvnm.ttf',
#  'C:\\Windows\\Fonts\\VIVALDII.TTF',
#  'c:\\windows\\fonts\\hack-bold.ttf',
#  'C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\Windows\\Fonts\\MyriadPro-Regular.otf',
#  'c:\\windows\\fonts\\perbi___.ttf',
#  'c:\\windows\\fonts\\nuevastd-bold.otf',
#  'C:\\Windows\\Fonts\\kaiu.ttf',
#  'C:\\Windows\\Fonts\\upcki.ttf',
#  'c:\\windows\\fonts\\majallab.ttf',
#  ...]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc_context
import matplotlib.patches as mpatches

fig, all_ax = plt.subplots(3, 2, figsize=(4, 6), tight_layout=True)

def demo(ax_top, ax_mid, ax_bottom, rcparams, label):
    labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
    fracs = [15, 30, 45, 10]

    explode = (0, 0.05, 0, 0)

    ax_top.set_title(label)

    with rc_context(rc=rcparams):
        ax_top.pie(fracs, labels=labels)
        ax_top.set_aspect('equal')
        ax_mid.bar(range(len(fracs)), fracs, tick_label=labels)
        plt.setp(ax_mid.get_xticklabels(), rotation=-45)
        grid = np.mgrid[0.2:0.8:3j, 0.2:0.8:3j].reshape(2, -1).T

        ax_bottom.set_xlim(0, .75)
        ax_bottom.set_ylim(0, .75)
        ax_bottom.add_artist(mpatches.Rectangle(grid[1] - [0.025, 0.05],
                                                0.05, 0.1))
        ax_bottom.add_artist(mpatches.RegularPolygon(grid[3], 5, 0.1))
        ax_bottom.add_artist(mpatches.Ellipse(grid[4], 0.2, 0.1))
        ax_bottom.add_artist(mpatches.Circle(grid[0], 0.1))
        ax_bottom.axis('off')

demo(*all_ax[:, 0], rcparams={'patch.force_edgecolor': True,
                              'patch.facecolor': 'b'}, label='classic')
demo(*all_ax[:, 1], rcparams={}, label='v2.0')
# Out:
# c:\users\claire\appdata\local\programs\python\python36\lib\site-packages\matplotlib\figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc_context
import matplotlib.patches as mpatches

fig, all_ax = plt.subplots(3, 2, figsize=(4, 6), tight_layout=True)

def demo(ax_top, ax_mid, ax_bottom, rcparams, label):
    labels = ['Like','Love','Haha','Wow','Sad','Angry']
    rxns = [42,24,12,16,4,2]
    total = sum(rxns)
    fracs = [x/total for x in rxns]

    explode = (0, 0.05, 0, 0)

    ax_top.set_title(label)

    with rc_context(rc=rcparams):
        ax_top.pie(fracs, labels=labels)
        ax_top.set_aspect('equal')
        ax_mid.bar(range(len(fracs)), fracs, tick_label=labels)
        plt.setp(ax_mid.get_xticklabels(), rotation=-45)
        grid = np.mgrid[0.2:0.8:3j, 0.2:0.8:3j].reshape(2, -1).T

        ax_bottom.set_xlim(0, .75)
        ax_bottom.set_ylim(0, .75)
        ax_bottom.add_artist(mpatches.Rectangle(grid[1] - [0.025, 0.05],0.05, 0.1))
        ax_bottom.add_artist(mpatches.RegularPolygon(grid[3], 5, 0.1))
        ax_bottom.add_artist(mpatches.Ellipse(grid[4], 0.2, 0.1))
        ax_bottom.add_artist(mpatches.Circle(grid[0], 0.1))
        ax_bottom.axis('off')

demo(*all_ax[:, 0], rcparams={'patch.force_edgecolor': True,
                              'patch.facecolor': 'b'}, label='classic')
demo(*all_ax[:, 1], rcparams={}, label='v2.0')
# Out:
# c:\users\claire\appdata\local\programs\python\python36\lib\site-packages\matplotlib\figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc_context
import matplotlib.patches as mpatches

fig, all_ax = plt.subplots(1, 2, figsize=(4, 2), tight_layout=True)

def demo(ax_top, rcparams, label):
    labels = ['Like','Love','Haha','Wow','Sad','Angry']
    rxns = [42,24,12,16,4,2]
    total = sum(rxns)
    fracs = [x/total for x in rxns]
    colors = ["#3366cc", "#dc3912", "#ff9900", "#109618", "#990099", "#0099c6", "#dd4477", "#66aa00", "#b82e2e", "#316395", "#994499", "#22aa99", "#aaaa11", "#6633cc", "#e67300", "#8b0707", "#651067", "#329262", "#5574a6", "#3b3eac"]

    explode = (0, 0.05, 0, 0)

    ax_top.set_title(label)

    with rc_context(rc=rcparams):
        ax_top.pie(fracs, labels=labels,colors=colors)
        ax_top.set_aspect('equal')
        grid = np.mgrid[0.2:0.8:3j, 0.2:0.8:3j].reshape(2, -1).T

demo(all_ax[0], rcparams={'patch.force_edgecolor': True,
                              'patch.facecolor': 'b'}, label='classic')
demo(all_ax[1], rcparams={}, label='v2.0')
# Out:
# c:\users\claire\appdata\local\programs\python\python36\lib\site-packages\matplotlib\figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
# https://www.quora.com/How-can-I-draw-a-heart-using-Python
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0,2*np.pi, 0.1)
x = 16*np.sin(t)**3
y = 13*np.cos(t)-5*np.cos(2*t)-2*np.cos(3*t)-np.cos(4*t)
plt.plot(x,y)
plt.savefig('heart.png',dpi=900)
plt.show()

# %%
# http://telliott99.blogspot.hk/2011/02/plotting-taylor-series-for-sine.html
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(3,2))
X = np.linspace(-np.pi, np.pi, 300)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)

plt.show()

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(3,2))
X = np.linspace(-np.pi, np.pi, 300)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="300">

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(3,2))
X = np.linspace(-np.pi, np.pi, 300)
C,S = np.cos(X), np.sin(X)

plt.plot(X,C)
plt.plot(X,S)

plt.show()

# %%
np.linspace(2,10,5,dtype=np.int32)
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
np.arange(2,11,2,dtype=np.int32)
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
evens = [2,4,6,8,10]
np.array(evens)
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
import pandas as pd
pd.DataFrame(evens)
# Out:
#     0
# 0   2
# 1   4
# 2   6
# 3   8
# 4  10
